# %% [markdown]
# ### Machine Learning using NLP of Wine Descriptions
# **Goal:** perform NLP on wine descriptions (using TF-IDF). Use the TF-IDF scores, along with other wine info, to build a machine learning algorithm that can predict the rating score for wine.
#
# **Input:**  A csv file of reviews with descripitons, varietals, region, and score from Wine Enthusiast Magazine. CSV was obtained from use zackthoutt on kaggle.com: [wine review data](https://www.kaggle.com/zynicide/wine-reviews). This dataset is 150,000 wine reviews, and only includes wines with scores from 80-100. The dataset has been cleaned to include only those reviews that include price (many had no listed price.) The cleaned dataset contains approximately 120,000 entries.
#
# **Expected Output:** A machine learnign algorithm that can take in:
# 1. Wine description (textual)
# 2. Country of origin
# 3. Designation (optional) - this is more specific data about the wine
# 4. Price
# 5. Province (optional)
# 6. Region
# 7. Varietal
# 8. Winery
#
# **The algorithm should then output a score (from 80-100).**
#
# Initially, we will create an algorithm that will attempt to predict score from *only* the text description, and will then compare this to an ML algorithm including text data in addition to the other wine data.

# %%
# import dependencies

import pandas as pd
import numpy as np
import os
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn import metrics

# %%
#load the data into a pandas dataframe
data = os.path.join('data/winemag-data-130k-prices-only.csv')
df = pd.read_csv(data)

# %%
#check to see that the data loaded correctly
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 1           2        US  Tart and snappy, the flavors of lime flesh and...
# 2           3        US  Pineapple rind, lemon pith and orange blossom ...
# 3           4        US  Much like the regular bottling from 2012, this...
# 4           5     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 0                            Avidagos      87   15.0           Douro
# 1                                 NaN      87   14.0          Oregon
# 2                Reserve Late Harvest      87   13.0        Michigan
# 3  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 4                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2         taster_name  \
# 0                  NaN                NaN          Roger Voss
# 1    Willamette Valley  Willamette Valley        Paul Gregutt
# 2  Lake Michigan Shore                NaN  Alexander Peartree
# 3    Willamette Valley  Willamette Valley        Paul Gregutt
# 4              Navarra                NaN   Michael Schachner
#
#   taster_twitter_handle                                              title  \
# 0            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 1           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 2                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 3           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 4           @wineschach  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
#
#               variety               winery
# 0      Portuguese Red  Quinta dos Avidagos
# 1          Pinot Gris            Rainstorm
# 2            Riesling           St. Julian
# 3          Pinot Noir         Sweet Cheeks
# 4  Tempranillo-Merlot               Tandem

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
#now we need to use the 'description' column, and perform some nlp on this to extract usable data.
#first we will construct a new df with just description text and points
text_df = pd.DataFrame({'points': df.points, 'description': df.description})
text_df.head()
# Out:
#                                          description  points
# 0  This is ripe and fruity, a wine that is smooth...      87
# 1  Tart and snappy, the flavors of lime flesh and...      87
# 2  Pineapple rind, lemon pith and orange blossom ...      87
# 3  Much like the regular bottling from 2012, this...      87
# 4  Blackberry and raspberry aromas show a typical...      87

# %% [markdown]
# We will now map points to stars to "bin" the points into 5 bins for easier classification

# %%
text_df['stars'] = text_df['points'].map({80:1, 81:1, 82:1, 83:1, 84:2, 85:2, 86:2, 87:2, 88:3, 89:3, 90:3, 91:3, 92:4, 93:4, 94:4, 95:4, 96:5, 97:5, 98:5, 99:5, 100:5})

# %%
text_df.head(10)
# Out:
#                                          description  points  stars
# 0  This is ripe and fruity, a wine that is smooth...      87      2
# 1  Tart and snappy, the flavors of lime flesh and...      87      2
# 2  Pineapple rind, lemon pith and orange blossom ...      87      2
# 3  Much like the regular bottling from 2012, this...      87      2
# 4  Blackberry and raspberry aromas show a typical...      87      2
# 5  Here's a bright, informal red that opens with ...      87      2
# 6  This dry and restrained wine offers spice in p...      87      2
# 7  Savory dried thyme notes accent sunnier flavor...      87      2
# 8  This has great depth of flavor with its fresh ...      87      2
# 9  Soft, supple plum envelopes an oaky structure ...      87      2

# %%
#let's first look at max and min length descriptions to see if there is any major difference
text_df['description'].map(lambda x: len(x)).max()
# Out:
# 829

# %%
text_df['description'].map(lambda x: len(x)).min()
# Out:
# 20

# %%
#let's add a new column that is the length. We will use this to feed into a predictive model to see if just the description
#length alone could be predictive of score.
text_df['length'] = text_df['description'].map(lambda x: len(x))
text_df.head()
# Out:
#                                          description  points  length
# 0  This is ripe and fruity, a wine that is smooth...      87     227
# 1  Tart and snappy, the flavors of lime flesh and...      87     186
# 2  Pineapple rind, lemon pith and orange blossom ...      87     199
# 3  Much like the regular bottling from 2012, this...      87     249
# 4  Blackberry and raspberry aromas show a typical...      87     261

# %%
text_df['description'].map(lambda x: len(x)).mean()
# Out:
# 244.24520768753874

# %%
Q = text_df.length.values
Q
# Out:
# array([227, 186, 199, ..., 225, 216, 169], dtype=int64)

# %%
Z = text_df.length.values.reshape(-1,1)
Z
# Out:
# array([[227],
#        [186],
#        [199],
#        ...,
#        [225],
#        [216],
#        [169]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
Z_train, Z_test, y_train, y_test = train_test_split(Z, y, random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB
Zmnb = MultinomialNB().fit(Z_train, y_train)

# %%
print(f"Training Data Score: {Zmnb.score(Z_train, y_train)}")
# Out:
# Training Data Score: 0.13176312395983733

# %%
print(Zmnb.predict(Z_train[5][0]))
print(y_train[5])
# Out:
# [88]
# 90

# %%
X = text_df.description.tolist()
y = text_df.points.values

# %%
y = text_df.stars.values

# %%
y
# Out:
# array([2, 2, 2, ..., 3, 3, 3], dtype=int64)

# %%
#import train test split to split our data into a training set and a testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
len(X_train)
# Out:
# 90731

# %%
X_train
# Out:
# ["An unusual blend of Riesling, Albariño and Sauvignon Blanc that is largely neutral on the nose and then waxy, honeyed and pithy in the mouth. Along the way there's an appealing dry, melony, petrol character and some good old-fashioned tang. A breed unto itself.",
#  "Coronato is a robust, modern super Tuscan only produced for export markets. Indeed, you can sense a New World appeal within its rich, succulent fabric thanks to penetrating notes of coffee, espresso, tar, aniseed, chocolate and bursting cherry. It's soft and velvety with enormous charm.",
#  "This isn't the most powerful, impressive Pinot Noir from the Sonoma Coast, but it has a lot going for it. It's bone dry, crisply acidic and elegant on the palate, with a flavor of sour cherry candy that's savory and clean. Drink now.",
#  "Alluring aromas of cocoa powder, berry fruits, graphite and raw oak lead to a jammy palate with density and weight. This old-vines Monastrell tastes of chocolaty oak and herbal blackberry. On the finish, it's tight and rugged, with mildly scratchy tannins and a saucy aftertaste. Drink through 2022.",
#  'For the vintage, this is a surprisingly lean wine. Some juicy fruit is still struggling out of the very dry tannic shell. Acidity is a dominant character of this firm, dry wine.',
#  'Smoke, spice and earth notes mark this deeply mineral auslese, adding depth and complexity to the sunny palate and peach and apricot flavors. A beautifully executed calibration of savory and sweet, it finishes with a twang of struck steel and lime.',
#  "Firmer and more tannic than many Hawke's Bay Syrahs, this is nonetheless classy, with gentle cracked-pepper notes and ripe blueberries upfront, followed by layers of blackberries, black olives and spice. The lingering finish features bright berries underscored by coffee grounds. Drink 2018–2025.",
#  'A sweet style of aged tawny, it has rich caramel flavors that combine with sultanas and almonds to give a ripe and generous wine. It has kept plenty of fresh fruitiness while moving towards wood aging.',
#  "Opulent and elegant, this brilliant deep-gold Tokaji has aromas of vanilla caramel, crème brûlée and candied apricot. On the palate, crisp acidity clears the path for flavors of preserved apricot and candied apple. It's full and round in the mouth, and delightful on its own or served with cheese.",
#  'With too much smoky toast, this gives a hard, extracted feel with licorice rather than fruit. Tannins are dense and hints of juicy fruitiness only appear in the background.',
#  "Very dry, tart and brittle, this Pinot, from a famous old vineyard that pioneered the Napa side of Carneros, isn't very lush right now. The cherryskin flavors are more bitter and tannic than you expect from most Pinot Noirs. Really needs lamb, steak or similar rich fare to wake it up.",
#  'A good Merlot that shows a fine structure, without much complexity. The wine is dry and tannic and soft, with blackberry, black cherry, plum and oak flavors. Ready now.',
#  'Saline and nettle aromas are a lot like underripe Sauvignon Blanc. This is a sour, cutting wine with flavors of lime, grapefruit and underripe passion fruit. The finish is overly acidic and citric.',
#  "Red in color, with sweet aromas of sugar beet, Red Delicious apple and cherry. It feels zesty, with simple flavors of red fruit and red apple. The finish is dry and a touch peppery. Drink immediately while it's fresh.",
#  "A nose of herbs, kiwi, smoke and minerals gives this white an intriguing start. On the palate, it's crisp and clean, with flavors of tropical fruit, herbs and spice unfolding over a minerally backbone. Ageable and terroir driven.",
#  'A blend of Sauvignon Blanc, Chenin Blanc and Sémillon, it tastes like green apples sprinkled with herbs and white pepper, on a smooth texture with fairly full body. An appealing intensity lingers on the finish.',
#  'This attractively priced wine has nice acidity and subtle flavors of pear and lemon. A pronounced swaddling in oak reveals itself on the nose and mid-palate. Enjoy it with food on the richer side.',
#  "In keeping with the dry style that marks Jeaunaux-Robin Champagne, this is a taut, crisply fruity wine. It has light, bright fruits with a touch of more mature toast and cookie flavors. It's just ready to drink.",
#  'Spicy Asian pear dominates in this low-to-no-oak white, medium-bodied and jumping in savory thyme. Aromas of peaches also come into play, before this wine finishes crisp and clean.',
#  "This basic Cabernet opens with standard berry, plum and herbal aromas. It's racy and tight on the tongue, with a mix of berry, chocolate and minty green flavors. The finish is spicy but not very fruity or complex. This is good as a pizza wine.",
#  'Extremely thick, soft and extracted, this delivers flavors of ripe fruit, cinnamon stick, honey, barbecue sauce, cured meat and dried apple skin. Savory tones of leather and button mushroom show up later.',
#  "This is an attractive, fruity wine that's dominated by black currant and damson flavors. It is layered with acidity and light tannins. Drink this year.",
#  'This wine has aromas of black plum and black raspberry, with flavors of tart cherry and ripe plum on the palate. The tannins have a bit of grip and the finish is persistent.',
#  "Slightly sweet and powdery smelling, with simple creaminess to the orange-influenced nose. The palate is solid and plump, with basic citrus flavors that shouldn't steer you wrong. Nice feel and a good but regular finish seal the deal.",
#  "It is rare to find Tinta Barroca on its own. Normally it is used for blending in Port. Here, though, it is in all its ripe fruit glory, an attractive, relatively lightweight wine. It's for drinking now, with red berry fruits right to the fore.",
#  'A powerful, almost overbearing oak influence makes this wine bombastic. Toasty, maple sugar and smoked bacon flavors come from heavily charred new oak barrels or oak add-ins. It has a very dark color, full body, plenty of tannins and a smoky, oaky finish.',
#  'Herbal, leathery aromas are horsey and sharp. This feels rugged and choppy, then tastes baked and herbal, like a mix of stewed fruits, oregano, cured meat and pepper. A grassy, herbal finish does little to bring it around.',
#  "This is made in a delicate, acidic and bone dry style. Some will say it lacks richness—and it does, by Napa standards. But it's quite an elegant wine, silky and light, with a hint of blackberry and tobacco flavor.",
#  'Soft and creamily fruity, this is an attractive, fresh wine. It has citrus fruit and apple-skin flavors and crisp, clean acidity. For drinking over the next year.',
#  'A very structured, firm wine with excellent acidity and dark, dry tannins. The alcohol does show through, but the wine is firm and very dense, a big success from this Lurton family owned property.',
#  "With 15.4% alcohol by volume, this is arguably Lail's ripest, hottest Cabernet ever. It certainly has flashy blackberry and cherry jam flavors, with plenty of toasty oak, but there's a raisin-and-prune, overripe finish. Could age, but it's more likely that the heat will pinch in within six years, crushing the fruit.",
#  'A generous, smooth texture and nicely bright flavors of lemon, lime and apple make this a satisfying wine. It is medium to full bodied, soft in acidity, but fresh in flavor. It should be a winner for large groups.',
#  "This opens with earthy underbrush, violet and red berry aromas. The palate is bright, with tart red cherry and ripe raspberry accented by notes of pepper and baking spice. It's vibrant and calls out for hearty pastas or pecorino cheese.",
#  'Sweet new wood goes with rich plum skins in a wine that has a firm structure. The richness of the wine revolves around sweet cherries and juicy acidity. With the wood still dominant, it needs at least five years to settle down.',
#  'The gorgeously opaque ruby color raises high hopes. However, the undistinguished, earthy nose fails to deliver. The lush palate is a step up, with red berry soup flavors interwoven with an odd ashy note. Long finish. Drink up.',
#  'A blend of 55% Cabernet Sauvignon, 25% Shiraz and 5% each of Merlot, Cabernet Franc, Malbec and Petit Verdot, this rich and approachable wine boasts lush aromas and flavors of brambly black berry, cherry and currant alongside notes of violet and chocolate fudge. The mouthfeel is like crushed velvet, with a creamy texture and a decadent finish reminiscent of chocolate-covered espresso beans.',
#  'An honest and very ripe take on Australian Chardonnay, with opulent notes of fig, pineapple and guava underscored by crisp lemon and a faint spritz that refresh the palate. The short-to-medium finish turns a bit soft. Quite likable on the whole. Try with lobster.',
#  "For an entry level wine, this is impressive, offering hints of grapefruit pith, bergamot and smoke on the nose and following those up with some meaty-mushroomy notes on the palate. It's not typical, but boasts a silky texture and a unqieu combination of citrus and umami that lingers nicely on the finish.",
#  "Negociant Cameron Hughes got his hands on some seriously good Cabernet to come out with this beauty. It's soft enough to drink right away, with luxurious tannins framing ripe, sweet flavors of blackberries, cherries and licorice. Sweet oak gives a rich layer of toast. Drink now.",
#  "Whereas many Syrahs from this vintage from the Rocks District show more fruit than usual, this wine is clearly rooted in the stones. It's aromatically expressive with black olive, crushed flowers, mineral, black pepper and an earthy funk. Flavors are silky soft in feel, with a well-balanced mixture of fruit and savory notes that leads to a lingering finish.",
#  'Full-volume cherry and cassis are in the lead on the nose. This blend of Cabernet Sauvignon, Cabernet Franc and Carmenère is robust and ripe. Raspberry, red plum, strawberry and pie cherry flavors cover the full red-fruit spectrum, while the finish remains fruity and bright, with a ton of energy. Drink through 2022.',
#  'The 2009 vintage has been kind to Cascina Morassino. This bright Barbaresco opens with plump aromas of ripe fruit and cherry, showing both dense extraction and impressive aromatic intensity. Silky and long, it represents the best of the Nebbiolo grape.',
#  'This is a wine that brings out all the bright fruit of the vintage. It has classic black-currant flavors and crisp acidity. The tannins are a firm supporting act to this wine that will develop well over the medium term.',
#  "This is a beautifully mature Champagne with layers of toast and almond flavors overlaying its rich white fruit. It's concentrated and tense with minerality and acidity within a framework of broad ripeness. Drink now.",
#  'This wine opens with aromas of burned tire rubber and asphalt. The palate offers bitter sensations of grilled sage, oak extract and roasted coffee beans alongside tongue-drying wood tannins.',
#  'This is an attractive, round wine. The ripe red-fruit character is balanced by a tangy, zesty lemon texture that gives freshness plus a touch of tannic structure. Very dry and spicy in the mouth, it will be good with food.',
#  'This new cuvée is 60% Malbec, 35% Syrah and the rest Merlot. It seems to have been given extra barrel time, and the overpowering and heavy toast scents and flavors dominate. The raspberry fruit flavors are somewhat buried as a result, and the wine seems over-matched. But more bottle age may help to open it up.',
#  "While bright cherry and berry aromatics take a bit of aeration and coaxing to flourish, this four-square wine calibrates juicy primary red fruit with cool touches of menthol and cranberry acidity. It's approachably fruity and framed in soft delicate tannins. Drink now.",
#  'Aromatically reminiscent of creme brûlée, this delightful Mendocino-grown wine, made from organically grown grapes, is crisp, clean and bright with grapefruit flavor. Textured, and with some flesh to its bones, it should pair especially well with wintertime shellfish.',
#  'White peach, melon and lime flavors are pure and pristine. A kiss of honey sweetens the palate, lingering softly alongside a spritz of lemony acidity. Enjoy now through 2016 for its crystalline character.',
#  'This small-production, barrel-fermented blend of white Tempranillo and Sauvignon Blanc smells neutral and fresh except for some barrel notes. It has a mix of spice, toast, citrus, almond and melon flavors. It spreads out on the finish, tasting spicy and cidery.',
#  "Organically grown grapes are vinified in all stainless steel, resulting in this fresh, delightfully textural wine. Lime, pineapple and lemon verbena flavors are backed with refreshing minerality. It's clean and crisply delicious.",
#  'Spunky raspberry aromas give this Tempranillo-led blend a fresh bouquet. The palate is snappy, a little high in acidity, and plenty zippy, with plum and cherry flavors. Finishes with length and some scour. Nice for everyday drinking; best with basic foods.',
#  "This blend of 50% Cabernet Sauvignon, 31% Cabernet Franc and 19% Merlot has aromas of toast, fresh-brewed coffee, graphite, dried herbs and milk chocolate. It's silky and elegant yet densely flavored, backed by grainy tannins.",
#  "Inky tones of blackberry, plum and spice come to the forefront of what is a simple but generous red wine. There's bulk and pulp here but the wine also has firm tannins and good structure to keep it balanced.",
#  "A warm, southern feeling wine, it has herbs, spice and rich tannins as well as a crisper feel of acidity. Fruity, full of black currant and red berry fruits, forward and ripe. It's not for aging.",
#  'The aromas are all high toned, with barrel notes of exotic spice, vanilla and medicine cabinet. The red-fruit flavors bring a sense of elegance and distinction.',
#  "J has taken the unusual step of blending Pinot Noir with Pinot Meunier, which is not so strange, but also with Pinotage, which is practically unheard of. The addition of the latter certainly makes the wine darker, heavier and more tannic than it ordinarily would be. It also brings an earthiness to Pinot's vibrant cherries. It's an oddball, but a charming one to drink with rich winter stews.",
#  'Simple and jammy, although tasty enough, with lip-smacking, candied flavors of cherries, raspberries and spicy mocha. Feels light and silky in the mouth, with gentle acids and tannins.',
#  'Rich and thick, this full-bodied, ripely bold wine has small amounts of Petite Sirah, Petit Verdot, Syrah, Merlot and Cabernet Franc. Mocha chocolate meets blackberry jam washed down in fresh-brewed coffee, making for a memorable experience.',
#  'Sorelle Bronca is a benchmark winery that consistently delivers one of the most elegant and refined expressions of Prosecco available today. This opens with drying mineral notes and feminine touches of honey and white rose on the finish.',
#  "Rich as chocolate cake, this bold wine is adorned with fresh berry flavors, its body full and concentrated. Soft like velvet curtains, it's a ripe expression of the vineyard in a ripe, picture-perfect year.",
#  'Aromas suggest oak, vanilla, bell pepper and cassis. The palate offers black cherry, cranberry, vanilla, mocha and oak alongside astringent, drying tannins.',
#  'This organic Chardonnay offers notes of soft pear, grass and citrus on the nose, while sweet citrus oil dominates the medium- weight mouth. A touch of melon rind unfolds on the short finish. Easy to drink, and drink now.',
#  'An immensely structured wine, packed with dark tannins promising aging potential. It is complex, powerful, layered with new wood and concentration, finishing with dark plum fruits and acidity.',
#  'Exuberant aromas of espresso, smoke and dark fruit leap up from the glass. The palate is considerably more reserved with fruit and earth flavors that linger.',
#  'Fresh apple and lemon on the palate of this Lake Erie Riesling are pleasant, but overwhelmed by oddly perfumed lemon-pine and floral notes. Simple and a bit savory. Drink now.',
#  'The best of the 2009 lineup from Willamette Valley Vineyards, this Eola-Amity Hills single-vineyard offering has the most complexity, in both nose and mouthfeel. Balanced fruits fill the palate, with spicy hints of earth, leaf and a wash of barrel-induced mocha.',
#  'Dusty smelling and a touch dilute on the nose, this Viura-Chardonnay blend displays aromas of green apple, citrus and vanilla. The palate is juicy, citric and clean, with tangerine, lemon peel and white grapefruit flavors. This is an ideal quaffing wine.',
#  'Citrus-edged sweetness is far more apparent on the palate than the nose, but here it delivers wonderful hints of lemon oil and candied zest, cut through by lively acidity against hints of tropical mango. A wonderfully toned BA, this will pair well with both cheese and dessert.',
#  'Blending fruit from four vineyards, this opens with dusty aromatics of rose petals, baking spices and cocoa. The mouthfeel continues in a pleasantly dusty vein, showing tart berry and pie-cherry flavors with a lick of mocha.',
#  "This Prosecco Brut (made with 5% Chardonnay for extra smoothness) delivers floral aromas of dried lavender and rose backed by mineral tones and pulpy peach. It's a lively and generous wine made by Franco Adami, one of the most charismatic and enthusiastic producers in Prosecco land.",
#  "A full, rich wine, showing red fruits at their best. It has structure and layers of bright acidity. It's not a wine for long aging, likely to be at its best in three years time.",
#  "This is sourced from 1970s-era vines. It's an almost ethereal weave of berry, saffron, mint, cola and tea, all wreathed in light smoke. It shows lovely complexity for such a young wine, and it's got the balance and structure to age nicely. Drink now through 2025.",
#  "Pato's pair of old vine wines, a red and this white, are beautifully complex. With its rich melon, tropical fruits, spice and light toastiness, this wine is concentrated with still-young acidity and currant fruit flavors. It's a great wine that needs to develop before drinking. Wait until 2016.",
#  'This blend of local Douro white grapes with, unusually, Chenin Blanc, is delicious. With its wood-aged touch and rich creamy texture, the wine is generous and full. It has attractive acidity as well, emphasizing the apple and grapefruit fruit. The wine will be even better from 2018.',
#  'Made entirely with the native grape Trebbiano Spoletino, this opens with aromas of acacia flower, chamomile and a whiff of tropical fruit. The round medium-bodied palate offers ripe honeydew melon and nectarine zest alongside fresh acidity.',
#  'This wood-aged wine shows dark berry fruits and a dusty structure. That goes with the juicy fruitiness that is perfumed, fresh and spicy. The wine has a stalky aftertaste with plenty of acidity. Drink now.',
#  'Ripe black-plum and black-cherry aromas lead the nose. This is full in body, with comfortable tannins. Blackberry and baked blueberry flavors end with chocolaty, herbal notes and a coating of blackened toast.',
#  'A sour tinge of toasty oak invites one in aromatically and taste-wise in this vineyard-designate, from such a stellar Westside Road site. Gravenstein apple and melon pique the palate while it remains balanced and beautifully textured through the spicy finish.',
#  "Brimming with ripe black plum and cherry flavors, this densely concentrated wine is unabashedly fruity and forward. It's well balanced though, showcasing crisp acidity and nuanced hints of rose petal and granite. Fine-grained but penetrating tannins persist on the finish.",
#  "Unripe green notes of leaves detract from this wine's enjoyment. It's crisp in acidity, with some pure Meyer lemon, lime and fig flavors, but that vegetal note is bothersome.",
#  "This is drinkable but not overly interesting, with a good berry flavor. It's marked with an off-putting aroma of cigarette ash, and it feels raw.",
#  'Composed, complex and complete, this mellow wine is very comfortable in its skin. Touches of oak, tobacco, dried plum and cardamom fill the aroma, and ripe but not overripe black cherry, tamarind and cola flavors flood the palate, supported by fine-grained tannins and medium-full body.',
#  'Barely there but intriguing notes of pears draw you in first. The soft body promises refreshment and rounded pleasure, with just enough phenolic texture and a hint of salty minerality.',
#  'Dense and well structured, this is going to be an attractive wine. It has blackberry fruit, plenty of crisp acidity and a structured aftertaste. Drink from 2018.',
#  "A restrained nose softly hints at tart berry and citrus. The palate is fresh but less precise when it comes to fruit: the body is light, dry and fresh, with a lasting note of citrus zestiness. With a clean finish and a tiny hint of grip, it's a wonderful rosé for the table.",
#  'Aromas of blackberry, plum, coffee and toast lead the nose. The full-bodied palate offers dried black cherry, toasted oak, coconut and oak-driven spice alongside assertive tannins that leave a drying finish. Drink soon before the remaining fruit disappears.',
#  'Bougros is one of the richest, opulent of the Grand Cru Chablis. In this fruit-driven year, the wine is wonderfully spicy, rich and full of fine fruit. Yellow fruits dominate the balancing citrus and wood flavors. It is so forward that it could be drunk now, but this fine wine will be much better from 2019',
#  'Scents of bacon fat from the new French oak introduce a tight young wine. The cured meat aromas and flavors somehow suggest a splash of Syrah in the blend, though none is noted. Give it a couple more years to smooth out and let the fruit come through.',
#  "This wine shows everything that Chardonnay lovers want. It's enormously rich and ripe in mango, pineapple, orange and peach flavors, enriched with sweet new oak and creamy lees. Drink now.",
#  'This fruity wine is ripe with black fruits and generous tannins. It has plenty of acidity to balance the fruit, giving a wine that is both crisp and packed with fruit. The structure is already just right. Drink from 2018.',
#  "The color is almost black, and lots of dark berry and black pepper aromas come out. This wine's flavors are even more pronounced, tasting peppery, meaty and like boysenberries. Dense \xadtannins make the mouthfeel thick and layered. A lingering finish attests to its considerable concentration.",
#  'Big, fat Pinot Gris, with the typical spice and ripe fruit. The wine is full and round, attractively filled with peach fruits and a hint of fine acidity. Screw cap.',
#  'Firm and structured, this has dense tannins as well as fruity character. Both the texture and the black plum fruits are concentrated. Flavors of wood aging have smoothed out the naturally stalky character of the fruit. Drink from 2016.',
#  "You can quibble with the price, but there's no doubt about the quality of this Zin. It's extraordinarily deeply flavored, offering waves of wild cherries, cola, anise, molé sauce, pepper spice and sandalwood, wrapped into profoundly fine tannins, and with a long, dry finish. Drink this near-perfect Zinfandel over the next six years.",
#  'Aromas of tire rubber, herb and red fruit lead to soft, plush cranberry and cherry flavors that linger.',
#  'Acidic and tart, with cherryskin, orange pekoe tea, thyme and spice flavors that finish dry.',
#  'From a traditional vineyard with old vines, this is a dense and structured wine. It has minerality, dark black fruits, a tense texture and a dry, tannic core. Drink from 2014.',
#  'What a fine Chardonnay. Made in a bone dry, minerally style, it may not have the immediately seductive quality of some Chards, but it does show a Chablis-like elegance that makes it a natural for food pairing, with its fine citrus and steel tang and mouthwatering acidity.',
#  'The wine comes from one of the cru estates followed by this negociant house. It is a light, ripe and fruity wine. With its attractive red-berry flavors, finished with crisp acidity, it is accessible and ready to drink.',
#  'Bramble and cedar, along with plenty of toasty vanillin oak. Black currant is the dominant fruit; the mouthfeel is appropriately big, and the finish turns a bit dry, but with proper length. Very nice in the typical Napa mold.',
#  'Especially for a more affordable bottling, Joey Tensley packs in a ton of density on this bottling, from the color to the nose to the palate. Hearty aromas of black currant, charred blackberry, dusty sagebrush and a hint of caramel drop into a deep and rich but not overripe palate of tar and blackened fruit. Soft tannins coat the mouth fully.',
#  "A very nice Zinfandel, rich and spicy, with black currant, dark chocolate, raisin, tobacco, pepper and cedar flavors. It's a bit overripe, especially in the finish. Drink up.",
#  'Leather and a mild green funkiness surround spicy berry and cherry aromas. This feels rather heavy and lacking in agility. Grapey flavors of baked berry fruits are overweight on a savory-tasting finish.',
#  'This is a big, concentrated and rather Burgundian Pinot Noir. It shows powerful flavors of cherry pie, cola, rhubarbs, pomegranates and dried herbs, with an earthy, mushroomy complexity. Feels young and tannic and thick in wood sap, yet its future is hard to predict.',
#  "Besides the Malbec, there is also 12% Cabernet Sauvignon in the blend. The grapes are from the Gold Vineyards in the Rogue Valley. Aged 13 months in French oak, it's showing a big burst of vanilla in both nose and flavor, along with cranberry fruit and some rugged dusty tannins. Another year of bottle age would help to integrate the oak a bit further.",
#  'Rabajà is among the most celebrated single vineyards in Barbaresco. The cru is known for its elegant yet muscular wines that perform well either aged or when drunk young. This expression exhibits notes of raspberry and cherry with shadings of vanilla and spice. It also shows some creamy or lactic notes of white chocolate that will dissolve within a few years.',
#  'This is a concentrated wine, full of blackberry fruits with acidity and spice. The wood-aging character is balancing out well, giving structure without dominating the fruit. Drink from 2020. Grapes are vinified by variety and plot from the 60-acre vineyard of Cabernet Sauvignon (55%), Merlot (40%) and Petit Verdot (5%). The property was purchased by Jean-Christophe Mau in 2004.',
#  'Malolactic notes and spice lead to plentiful stone-fruit flavors. Barrel notes provide accents.',
#  "Gazza Ladra is a chalky, but almost sweet smelling expression of Fiano from southern Italy with aromas of candied lemon and honeysuckle. It's thin and compact with a bright touch of acidity on the close.",
#  'Aromas of blue flower, dark berry, scorched earth and a whiff of oak spices come together in the glass. The palate offers dried cherry, game, ground pepper, toast and espresso alongside grippy, drying tannins.',
#  'Soft and light, this is attractively fruity although it lacks great depth of flavor. It is balanced, ripe and sweet, with touches of the wood aging and acidity coming through more strongly at the end.',
#  'Black and thick, a study in smoky oak and tar, this intense vineyard-designated Cabernet will behave better over time. Brawny tannins surround substantial layers of blackberry and coffee, the feel on the palate weighty and voluptuous. Cellar through 2026.',
#  'Richly textured and generously flavored, this wine shows how good Livermore Cabernet can be. Aged in new Hungarian barrels, it has cedar and spice aromas, seductive ripe fruit flavors and a mouth-filling, palate-soothing viscosity bolstered by loads of fine-grained tannins. Best from 2018.',
#  'A perfumed, aromatic wine, dry yet full of fresh, fragrant white fruit flavors. A steely edge is followed by hints of currants and a complex, still-youthful texture. Drink from 2015.',
#  'Baked earthy black-fruit aromas are followed by a blocky palate with jagged tannins and bold acidity. Blackberry, chocolate, coffee and raw-oak flavors finish with black cherry and plum notes as well as some hollowness.',
#  "There's something old-fashioned about this wine, in its strong, edgy tannins and rustic mouthfeel. Yet it's high and hot in alcohol, with extracted, jammy cherry and raisin flavors. Doesn't seem to be an ager, so drink now.",
#  'This medium-bodied wine opens with a squeeze of acidity and follows through with simple and straightforward citrus flavors.',
#  "Supple and full-bodied, this wine offers ample aromas and flavors of ripe cherries, supported by hints of cedar and vanilla. It's not super complex, but is a bold, flavorful wine with a softly dusty, lingering finish.",
#  "Very light in color, this bottling by the Coppola family shows sweeter aromas of Gravenstein apple, ripe pear, honeysuckle and tuberose on the nose. It's also a tad sweet on the palate, especially for today's sparkling standards, but will surely attract a wide fan base thanks to apple custard, cotton candy and plumeria-like flavors, all dissected by racy bubbles and acidity.",
#  'Mineral, lime and crisp apple aromas give it a precise, pure nose. And that same character exists on the palate and finish, where white peach, green banana and melon flavors are full and forward. Shows good concentration and quality for a large-production bubbly at this price.',
#  'This blend of Rabigato and Códega do Larinho grapes brings out the crisp acidity of a Douro white. The wine has a fragrant character with hedgerow fruits and white flower aromas. The aftertaste goes more towards yellow fruits while keeping all the freshness.',
#  'Heady exotic fruit, tomato vine and chopped herb aromas jump out of the glass. On the generous, savory palate, tangy acidity balances white peach, honeydew melon and juicy grapefruit flavors.',
#  "With many characteristics of the granite-soil based Dão, this is a dense, mineral and dark fruited wine. It has blackberry and plum-skin fruits as well as a firm, tannic core. Even though it's tightly structured now, it is drinkable, but would benefit from another year's aging.",
#  "The famous growers branch out into their own wines with aplomb in this 100% varietal wine, tangoing with a much sought-after grape from their property. Sanguine and gamy, it's structured in good acidity and low oak, showing a succulence of blackberry.",
#  "This reflects the Yarra region's Pinot Noir character well, combining earthy, cola- and beet-scented notes with well-ripened tannins and medium body. There's a fair bit of textural richness for such a modestly priced Pinot. Drink now.",
#  "A big, ripe and juicy wine that has open, soft tannins and layers of black fruits. Bold and forward, it's ready for drinking now–2018.",
#  "This wine is made from the same barrels as the producer's Finch Hollow offering, using the wine from the top of the barrels and left unfined and unfiltered. The result is an ethereal experience, creamy and crisp in golden apple and nectarine, its body rich, round, lush and delightfully satisfying.",
#  "Savory and deep, it carries lovely details of earth and herb, balanced against flavors of lightly spiced apples. As with all the Eyrie wines from this outstanding vintage, it's unique, compelling and utterly original.",
#  'Earthy black-fruit aromas include notes of cigar box. This feels tight and acidic, but with plenty of oak. Flavors of woodspice and vanilla are more dominant than plum and berry notes, while this is thick but not entirely thorough on the finish.',
#  "Grown on Antinori's original property, high on Atlas Peak, although you'd never know it from searching the front or back labels. It's a very fine wine, dry and elegantly constructed, with little of the baby fat over-the-topness that affects some Napa Cabs. Within that firm structure are extraordinarily complex blackberry, black currant and spicy plum flavors. Delicious now despite the firm tannins, and should develop over the next 8–10 years, at least.",
#  'The cold vintage left this wine tasting unripe. It has green, vegetal streaks of mint and green pea, but tastes oddly sweet, like a citrus candy coughdrop.',
#  'Hard, rubbery, leathery aromas are balanced off by black-fruit scents. This is tight on the palate, with condensed flavors of berry, plum and minty herbs. The finish holds onto that herbal character while showing solidity and adequate structure.',
#  "Seemingly picked on the early side, with slightly green, underripe flavors underscored by crisp acids and firm tannins. Has plenty of depth and concentration, but don't expect it to ever fully blossom. Try it now with rare steak.",
#  'Based in the village of Lancié in the heart of the Beaujolais crus, this producer has made a ripe wine that is full of black-cherry fruits and balanced tannins. It is concentrated and ripe, perfumed with a fresh, crisp aftertaste.',
#  "This shows the immediate appeal of Central Otago's 2013 vintage. Yes, the acids and tannins stick out a bit, but they're cushioned by loads of ripe berry fruit. Hints of dried bracken and chocolate add complexity, while the finish glides to long, dusty completion. Drink now–2018.",
#  'Earthy, baked aromas of ripe berry, raisin and leather come with a tobacco note. This is nice given the cold weather that drove the 2011 vintage. Round tannins and overall balance provide bedding for spicy flavors of blackberry, herbal notes, licorice and oak.',
#  'Light fruit flavors of apple and pear have been softened a bit with aging on the lees in neutral oak. This is a pleasant, simple, quaffable wine for every day enjoyment.',
#  "Lush aromas of cinnamon, black and red cherry, vanilla and toasted brioche show on this unabashedly potent and downright delicious bottling by the region's pioneering winery. Soft tannins joyously present rounded red-fruit and vanilla-cake flavors, with rich accents of cherry compote and chocolate chip cookie that are cut by streaks of bitterness and tartness. It's a voluptuous, attention-grabbing wine.",
#  "Pull's well-priced portfolio delivers consistent quality, and this 54% Syrah, 27% Petite Sirah, 16% Grenache, and 3% Viognier blend is appealing, with black cherry aromas lingering amidst rose petals and mint. Blackberry juice wins the palate, with a touch of black licorice and ample yet easygoing tannins.",
#  'Ripe black cherry and vanilla swirl around notes of cedar and dusty tannins, combining seamlessly on the palate. From an appellation not known for the variety, it does justice to mountain fruit and power, finishing with substance.',
#  'Aromas of apple, crushed stone and thyme come together on this vibrant white. The medium-bodied palate offers green pear, juicy nectarine, dried herb and flinty mineral alongside lively acidity. A note of bitter almond fills in the finish.',
#  "Soutiran regards this as its hallmark wine—its signature. It reveals the producer's preference for drier styles of Champagne, bringing out crisp fruitiness. It is packed with apple and orange zest flavors that are young although ready to drink.",
#  "Light in texture, this wine shows a fair amount of barrel influence aromatically. On the palate, it's similarly challenging to disregard the oak, which frames a mid-weight body marked by sour cherry.",
#  'This opens with delicate aromas that recall pear, yellow stone fruit and a whiff of almond. The juicy palate presents yellow peach, citrus and a hint of hazelnut alongside fresh acidity.',
#  "Scoring slightly higher than the Alderpoint vineyard-designated wine, this basic Humboldt County bottling bursts with with black cherry aroma. It's medium-bodied, free of oak-driven flavor and loaded with fruit. Lively acidity and mouth-filling texture keep the cherry and raspberry notes echoing through the finish, striking wonderful balance in an appetizing, mouthwatering package.",
#  'Tropical fruit, white flower-flavored candies, aromatic heirloom apples and a touch of honey come into crystalline focus on this wine by Joey Tensley and Alex Guarachi. Lime blossoms, Key lime crème fraîche and a touch of yogurt consume the energetic palate.',
#  'With lively spice flavors and delicious red apple and white currant flavors, this is a spicy wine that just keeps cool and lively. There is some pepper and tropical fruit, but this is more about great, fresh, green fruits.',
#  'Given time in both French oak and stainless-steel, this wine combines grapefruit with melon and stone fruit like apricot to offer an unctuous weight on the palate. It finishes dry and balanced with shy acidity.',
#  'This fine ripe wine is smooth and rich. Its acidity and apple-fruit aspect is balanced by richer yellow fruit and a touch of almonds. Drink this finely made wine now.',
#  'This is a light, fruity, apple-flavored wine. It has a really crisp character with a classic tangy texture from the 85% Chenin Blanc in the blend. The wine is fresh, fruity and ready to drink.',
#  'Burgundy producer Aegerter has come up with a bright and breezy Provence rosé whose style sums up the lighter side of these wines. It is fruity, fresh, very clean and crisp.',
#  'Aromas of cocoa, milk chocolate, spice and red berries are followed by tart luscious red-cherry and chocolate flavors. It shows a pleasing sense of balance.',
#  "Predominantly Syrah (80%) with Petite Sirah and Viognier, this wine conveys raspberries, cherries, flowers, black pepper and dark coffee. It's lighter in style with lip-smacking fruit and barrel flavors.",
#  'This smells rubbery, with oaky spice, but airing allows it to expand across a lively palate. Herbal, spicy red-berry flavors are strongest in the midpalate, while peppery flavors, rubbery tannins and scratchiness define the finish.',
#  'Roasted, soupy berry aromas lead to a sticky, heavy palate with a doughy build. This tastes mostly of baked, herbal tomato and plum, while cherry, spice, chocolate, coffee grinds and earthy flavors bring up the rear.',
#  'Chemical-leaning aromas jump out on a last-legs nose. This feels dull and low on pulse, with only a hint of acidity. Mealy bitter apricot flavors finish pithy.',
#  "Aromatic in black cherry and herb, this is a smooth, round Merlot that'll please many palates, balanced in pleasant fruity tones and vanilla oak.",
#  'Made in a ripe, appealing style, this has rich flavors of pineapple jam, tropical fruit, vanilla and buttered toast, brightened by crisp acidity.',
#  'The pear, nectarine and floral aromas seem to lack clarity. This wine is full of stone-fruit flavors that bring a touch of sweetness and lead to a warm finish.',
#  'A very intriguing nose of fresh dill and dried anise gives this plenty of aromatic lift, following through on the concentrated palate where ripe cherries join. Oak tannins lend additional structure but never dominate. While lovely now, this will certainly gain from a year or two in the cellar. Its soft, but full body is a triumph. Drink from 2016–2020.',
#  'Overworked and oaky, with vanilla, buttered toast and sweet caramel flavors dominating everything else. Buried beneath are pineapple and pear flavors.',
#  'This wine has an austere character that comes from the tight structure. There are only hints of possible fruit. It is likely to remain severe even as it matures.',
#  "This starts with a smoky aroma, like charred steak over the grill. Then highly concentrated fruit flavors zoom across the tongue, along with very firm tannins and powerful, ripe blackberry and blueberry flavors backed by a mouth-coating texture. It's an unusually focused and structured wine.",
#  'This wine is full of lovely aromas and flavors, but something unique about its grippy texture makes it soar. It begins with fresh, mineral-laced scents of Asian pear, yellow-grapefruit pith, crisp yellow apple and chalk. Then comes a palate full of yellow apple skins, lemon wedge and the slightest hint of grass, all served atop energetic, mouthwatering acidity.',
#  'The nose already hints at juicy ripeness, while the palate makes the promise manifest with an explosion of ripe and juicy red and black-cherry flavors. This wine is easy and fruit-driven, bouncing exuberantly on the palate. It can be chilled and would be fun at picnics where a lively but not heavy red with just a little grip is just the ticket.',
#  "This simple, fruity, red-berry-flavored wine has bright acidity along with soft tannins. It's a great barbecue style of wine, fruity and ready to go with grilled meat.",
#  "A first varietal offering from this winery, this offers notes of green herbs, bell pepper and wood spices. It's satiny in feel with plum flavors with the oak giving some chalkiness to the tannins.",
#  'Starts with a clean cherry and berry nose, which sets up the fresh, well-layered palate. Flavors of red fruits are ripe and medium sweet, while touches of oak, butter and pepper emerge on the finish. A tasty everyday wine.',
#  'The blend includes a bit of Merlot and Cabernet Franc (10% each). Weinbau and Sagemoor fruit make for a soft, instantly enjoyable red with smooth, supple flavors. Mixed red fruits, light spices and soft tannins lead through and into a gentle finish with a hint of dark chocolate.',
#  "This is an impressive wine that's full of fruit, structure and acidity. It's well balanced, rich and crisply fresh, with lively acidity on the finish—a real food-friendly rosé.",
#  "Here's a luminous and vibrant rosato from Sicily with a saturated pink color and thick aromas of ripe raspberry and forest fruit. It has good acidity and enough heft and density in the mouth to pair with pasta or fish soup.",
#  'This blend of native grapes (80% Caprettone and 20% Catalanesca) conveys delicate fragrances of Spanish broom and white fragrant flowers. The vibrant palate offers apple, citrus and peach accented with notes of Mediterranean herbs. Vinity Wine, Panebianco.',
#  'This is a soft, muddled and somewhat green wine, with sizable tannins and an earthy element of wet tobacco that will require strongly flavored food to enjoy.',
#  'The second wine of this legendary Douro estate is rich and full bodied. It has dark tannins along with generous red-berry fruits and juicy acidity. It will develop into a full, while accessible wine. Drink from 2020.',
#  'This concentrated Merlot is blended with smaller percentages of Petit Verdot, Cabernet Sauvignon, Cabernet Franc and Syrah. Dense in black licorice and toasty oak, the fruit character is dominated by red plum and berry aromas and flavors.',
#  'Winemaker Larry Schaffer proudly explores lesser-used varieties such as Cinsault, and makes compelling arguments in their favor. This bottling from Camp 4 Vineyard shows fresh and dried strawberry and slightly sour plum on the nose with a touch clove and dried ginger. The palate offers cranberry and hibiscus with red licorice spice, presented with lively acidity.',
#  'Onion skin orange in color, this is a full and fat wine. It has attractive red-berry fruit and just the right amount of acidity to keep it fresh and crisp. Drink now.',
#  'Blackberry syrup, loamy soils and light mint show on the nose of this bottling by self-made vintners Don and Jennifer Arndt. There is a tense and tarry tannic structure to the sip, with deep and brooding flavors of blackened purple fruit most prominent.',
#  'Made with 70% Carricante and 30% Catarratto, this elegantly structured wine has enticing aromas of Mediterranean herb, fragrant yellow flower, citrus and a whiff of acacia. The fresh, savory palate shows juicy lime, ripe pear, chopped herb and mineral alongside tangy acidity. The lingering finish closes crisp and clean.',
#  'Piercing, jabbing aromas of wood and berry fruits lead to a juicy, acidic, fresh feeling palate with light, oaky, generic flavors of minty berry, herbs and oak. A modest, oaky finish is undistinguished.',
#  "This comes from 30-year-old vines in the Quinta da Manoella, the family vineyard of Jorge Borges, one of the winemaking husband-and-wife team at Wine & Soul. This bottling shows the fruit-driven side of this vineyard, which also has 100-year-old vines. It's dense and solid, with powerful tannins that are beautifully integrated into the big plum fruits. The aftertaste is smooth, rich and concentrated.",
#  'Sourced from the Stillwater Creek vineyard this wine spent 20 months in 75% new French oak. Immediately appealing, it opens into a mix of cranberry, pomegranate and cherry fruit, annotated with light hints of sandalwood, cocoa and black tea.',
#  'Intensely juicy, this wine delivers tannins as well as red berry fruit flavors. Great acidity brings out a fresh side. The structure will push the wine forward and give it a good future. Drink from 2017.',
#  'This 100% Cabernet has scents of ripe black-skinned fruit, aromatic herb, new leather, baking spice and a balsamic note. The round savory palate offers black currant, stewed prune, herb, clove and a hint of star anise alongside polished, fine-grained tannins. Drink over the next several years.',
#  'Soft, ripe, red fruit-flavored Merlot gives a round character to this rich wine. It has plenty of spice, juicy acidity and gentle tannins that make it drinkable young.',
#  'The typical field blend from Vienna, full and deliciously spicy. It has elegance and style, a wine that waltzes across the palate, offering hints of lychee, pear and crisp citrus all finely integrated by tangy acidity. Screw cap.',
#  "Like most young Hunter Valley Semillons, this is starting out on the neutral, acidic side. Notes of melon and citrus rind only hint at the potential to be found in a few years' time. It's a little weightier than expected, with a silky mouthfeel and a long, gentle, lime-riddled finish.",
#  'This 65% Merlot wine is ripe, fruity and soft. Coming from a light vintage, it is ready to drink with its blackberry fruits and supporting tannins.',
#  'Jumpy and aggressive on the nose, with a mix of charred, burnt, meaty aromas and saline, this struggles to register. A grabby, sticky, roasted palate tastes burnt and herbal, while the finish is charred and chocolaty.',
#  'In a ripe Bordeaux year, Sauvignon Blanc goes towards tropical and yellow fruits, making it ripe while also light and crisp. This refreshing, rounded wine is ready to drink.',
#  'An attractive touch of toast emerges on this ripe, full-bodied wine. It has spice, apple and apricot flavors along with an edge of minerality. Drink now, although it will be better from 2016.',
#  "If you love massive Argentine reds with purity of fruit and fine oak, then this blend is up your alley. Toasty blackberry aromas come with plenty of oak grain, vanilla and depth. This is profoundly deep on the palate, while toasty blackberry, chocolate and peppery flavors finish with mocha and bracing tannins that aren't too rocky or hard. Drink through 2025.",
#  '. Its mouthfeel smacks hard with acidity, leaving a crisp expression of strawberry, raspberry and herb flavors. It turns warm, lactic and chocolaty on the finish.',
#  'Berry and cassis aromas are spicy and powerful, with integrated oak in support. This solid, tough wine features rugged but fair tannins. Savory berry, baked notes, leather and herbal flavors are very Cabernet-ish, while the finish is dry, firm and tannic. Age this until 2017–2022, or decant if drinking now.',
#  "This is a nice Bordeaux-style blend with pretty cherry and currant fruit and some cedar shadings, but lack the complexity of others in its style. It's straight forward, polite and restrained.",
#  'Polished aromas of roasted nuts, sea salt, Meyer lemon peel and onion skin show on the nose of this widely available bottling from the Chardonnay kings. The sip is a little bit flat in terms of texture and acidity, but there are compelling and satisfying flavors of roasted walnuts and pecans, with a citrusy acidity that rises toward the finish.',
#  'Medium yellow in the glass, this wine features a nose of citrus, with a touch of floral notes. It is bright on entry, and then fills the mouth with soft tannins and flavors of grapefruit, guava and pineapple that lead to a bright citrus splash on the finish.',
# ...
#  'Pencil lead and rubbery, mature berry aromas open this wine. The palate is driven by energetic, pounding tannins and flavors of black cherry and tomato, which become more prominent as the tannins and acid rebound. This is an indication of how Argentine Cabernet Sauvignon ages.',
#  'Rich and ripe, with soft tannins and black plum flavors. It is round, while still having a core of attractive tannins. The fruit dominates, giving a friendly, accessible wine.',
#  'From old vines in selected vineyards, this wine is richly endowed with dense black fruits and dusty tannins. Full bodied and intense with a ripe, jammy character, its fruit concentration is bolstered by wood aging. Drink from 2018.',
#  "Here's a ripe, slightly cooked Sangiovese from Puglia with a brownish color and full aromas of ripe raspberry and strawberry jam. It's chewy and slightly sour in the mouth with polished tannins. Drink now.",
#  'Pale peach in color, this wine offers bright notes of watermelon and cherry. It drinks a hair or two off dry, with plentiful juicy fruit flavors.',
#  'Tired red fruit lurks under the black-pepper and charred-oak flavors on the palate, though the woody, rustic mouthfeel is interesting. Nose is rather mute, with a little dried herb showing through.',
#  "Despite its robust body, there's a delicacy to pristine red cherry and cassis in this pretty Pinot Noir. It's not a richly concentrated wine, but nuanced elegantly by touches of crushed mineral, licorice and cocoa. Soft, feathery tannins guide a moderately long finish. Drink now through 2020.",
#  "Grapy aromas suggest minerals and iodine along with wet animal fur and plum. It's firm and tannic on the palate, with herbal, rooty plum and berry flavors and a tight finish.",
#  'Warm, furry aromas of olive, prune and animal hide are challenging. In the mouth, this cool-year Carmenère feels tartaric and narrow, with grating tannins. Fiery flavors of black fruits, raisin and oak are mildly salty and herbal, while the finish feels hot and tastes of minty oak and black fruits.',
#  'Packaged in what looks like a solid gold bottle, this easy sparkler offers fresh acidity and clean fruit aromas. The gold packaging gives this particular bottle a sassy, luxurious competitive edge.',
#  'Hard as nails in tannins, with mouth-numbing astringency. But the powerful fruit explodes right through, offering an array of blackberry jam, dark chocolate, raisin and anise flavors. Try cellaring it until at least 2019.',
#  "Sauvignon Blanc, yes, but it's a round, tropical fruit style of Sauvignon. It gives a rich texture and and a warm feel to the wine, reinforced by its soft aftertaste. It's ready to drink now.",
#  'Tasted in a group of wines considerably more expensive, including from Napa Valley, this Cab stood out for its purity, balance and restraint. Really impresses for its structure, so nicely tannic and firm, and the way the currant, blackberry and cherry fruit flavors marry seamlessly with smoky oak. Represents a real step forward in Paso Robles Cabernet Sauvignon.',
#  "Starts off slowly, but opens considerably with air—so much so that it's probably worth decanting as you might a bottle of young white Burgundy. It's buttery and full, yet possesses a stony mineral quality that gives it balance. Initial peppery-spicy notes on the finish smooth out the longer it sits in the glass. Editors' Choice.",
#  "Stewy, chewy and quite tannic this blend splits Petite Sirah, Mourvèdre and Grenache into thirds. It offers little in the way of fruit; instead it's mostly leathery earth.",
#  "New management, farming and winemaking practices at this producer, including a focus on smaller production, are remarkably on display in this delicious white. Golden pear and crunchy apple provide an unctuous, delightfully balanced experience that's crisp in underlying acidity and subtle baking spice.",
#  'This bottling from an iconic vineyard is subtle yet steady on the nose, with cinnamon and nutmeg spice giving character to a red-cherry base. The vibrant palate keeps the mouth watering, showing clove and more nutmeg atop sharper cranberry and warmer cherry fruit tones.',
#  'A beautiful, fragrant wine that is fresh with apples and pears and lightly mineral in character. It has great fruitiness and lively acidity that continues strong to the end. Drink now.',
#  'A pleasant, traditionally made Dolcetto, the Ratti shows black fruit aromas and flavors of smoked meat and soy. A well made, balanced wine, its only failing is its slightly sour aftertaste.',
#  "Dry and delicately structured, with sour cherry Life Saver flavors. There's a disagreeably green, unripe streak that is distracting.",
#  'The wine boasts a pretty golden hue and segues to tones of almond skin, stone fruit, nut and cardboard. It feels smooth and rich in the mouth and has some tart citrus flavors on the close.',
#  "Cabernet Sauvignon makes up half of this wine with the rest Syrah (40%) and Petit Verdot. Aromas of blackberry seed, spice, black licorice and dark fruit lead to ripe, full and appealing black-fruit flavors. It's a hedonistic delight.",
#  'Earthy, dense, smoky and charred, this Pinot is showing clear signs of coming from a warm year. Tomatoey acidity and a leathery quality drive the palate, while flavors of stewed, briny raspberry and plum are leathery and finish savory and slightly salty.',
#  'This always-impressive wine is a blend that pits local Alentejo grapes against Syrah and Petit Verdot. Concentrated and complex, it is packed both with black fruits and dark tannins. Intense acidity proclaims its youth and this powerful wine will need to age. Drink from 2019.',
#  "So ripe and fruity, it's almost too much of a good thing. Detonates on the palate with blasts of blackberries, cherries, raspberries, cola and cinnamon spice. Feels too soft, and could use greater dryness and structure, but it's a good BBQ sipper.",
#  "Shows distinct cool-climate acidity framing streamlined flavors of pineapples, lemons and limes, minerals and spices. It's an elegantly structured, clean wine that will satisfy Chardonnay lovers.",
#  'This crisp, lemon-flavored wine has a ripe, full character. It is rich with apples, apricots and delicious acidity at the end.',
#  'Initially a tightly textured, apple and pear skin flavored wine. As it opens up, it shows creamy, fresh fruit, with pear and white currant freshness, finished with green walnuts and a burst of acidity.',
#  'White-fruit aromas and a prickly scent of cactus or nettle opens this tight, citrusy old-vines Verdejo. Matching the aromas, this tastes of pithy citrus, grapefruit and green herbs. A racy finish fades out nicely.',
#  "Plenty of flavor, with tastes of black raspberry jam, cherry, tobacco and pepper. Has a nice texture, satiny and velvety, with good acidity. Straddles the border between simple and complex, but it's certainly tasty with a good, long finish.",
#  "This lightly bodied, elegant wine is subtle and crisp—a study in white pepper and leather that's both complex and tightly layered. Cool climate to its core, it shows floral aromas and flavors of rose petal and lavender as hints of rhubarb and tart cherry make their way onto the quiet palate.",
#  "There's good, mouthwatering acidity in this Viognier, but it's not enough to balance out the sweet directness of the fruit. Tastes like apricot, peach and pineapple jam, almost a dessert wine.",
#  'Soft supple tannins open a gateway of big bold respectable power and flavor in this vineyard designate from the famous Napa Valley grower. Black pepper, mountain-like sage, milk chocolate, cedar and pencil shavings all rise to the fore of this impressive, complex, interwoven wine that should do well in the cellar and be enjoyable now.',
#  'From an extreme coastal vineyard three miles north of Cambria, this bottling kicks off with peppery spice on the nose along with strong black olive, bay leaf, dill and a black-raspberry element on the edges. Lively underripe fruit tones power the palate, as does Kalamata olive, North African spice, coriander and tomato leaf.',
#  'Smooth and lightly toasty, this is a well-balanced, ripe wine. Attractive acidity gently supports the yellow fruits, rich texture and overall generous feel. Drink this delicious, full-bodied wine now.',
#  "Here is another great value from the Milbrandt brothers, based upon their impeccable vineyard sources (they own 1600 acres, mostly in the Wahluke Slope AVA). Dense and dark, ripe and compact, this Cab/Merlot/Petit Verdot blend brings plenty of macho and muscle, layers of black fruits, black smoke, black tea and black olives. Get the idea? It's a beautiful effort, and really shines at this price point.",
#  'Pure purple fruit and flower aromas hit the nose on this straight-ahead bottling, with plum candy, sour cherry and a touch of soy sauce as well. Strong energy and purple fruit show on the palate, along with violets and blueberries, proving floral and fairly tangy.',
#  'Gritty, earthy berry aromas lack refinement. This wine has a narrow, blocky mouthfeel and salty flavors of baked plum and carob. That same roasted, salty character carries over onto the finish.',
#  'Aged for 36 months in barriques and 24 months in large casks, this opens with aromas of coconut, toasted oak and spicy blackberry. The palate offers sour cherry, mocha, tobacco and roasted coffee bean. The palate starts smooth and creamy but austere wood tannins impart a mouth-drying finish. Drink through 2022.',
#  "Floral on the nose, this is a light, pretty Chardonnay steeped in straightforward citrus and apple. It has been aged partially in new French oak but doesn't come off as oaky.",
#  'Not considered a noble varietal, Carignane can offer pleasure, and this one does. ItÕs quite rich and smells and tastes Porty, with dark chocolate and raisin notes, although the official alcohol is a moderate 13.6%. The plummy flavors are powerful, the tannins and acids soft.',
#  'A dramatic Cabernet that immediately impresses for power and voluptuous texture. Dazzles with waves of blackberries, cassis and chocolate, wrapped into the smoothest tannins you can imagine. Winemaker Thomas Rivers Brown made this lovely 100% Cabernet from fruit grown in a warmer region of the Vaca Mountains. Drink now–2019.',
#  'A simple but attractive Côtes du Rhône, with impressively pure cherry-berry fruit, medium body and a slightly chunky feel. Drink it over the next couple of years.',
#  'Already entering maturity, the 2008 Silhouette is a blended red (Merlot, Zinfandel, Sangiovese and more) with spicy, toasty flavors. The fruit is drying out, and the wine turning generic, but still fine for near-term drinking.',
#  'There is a fine layer of minerality in this wine, coming from the dry stones of the vineyard. It produces a tight texture that dominates at this stage. Underneath, green and yellow fruits are waiting to come out, bringing with them a great lift of acidity and delicious refreshing crispness.',
#  'Ripe plum, coconut, vanilla and French oak aromas lead the nose. Youthfully assertive and austere, the palate offers toasted oak, licorice and espresso notes, set against a backdrop of bracing tannins that grip the finish. That structure should mellow and integrate with a few more years of bottle age.',
#  'Perfumed berry, iris and baking spice aromas float out of the glass. The firm palate offers mature wild cherry, ripe raspberry, licorice, menthol and chopped herb while assertive but refined tannins provide support.',
#  'This wine features inviting aromatics of fresh plum, coconut and strawberry. The palate entices with savory rhubarb, bay leaf, mint and cola. A tight core of structure partners with soft, plush tannins.',
#  'Crisp, minty, herbal aromas of berry and plum lead to a bright, rumbling, tannic palate with energy. Blackberry and chocolate flavors are good and earthy, while the finish is plump but braced by lively acidity. This is well made and satisfying for a basic roble wine.',
#  'This forceful Mencía blend pounds away with heavy oak, lemon and violet aromas. The palate is scorching, scouring and short on balance. Inky berry and bitter flavors come with overpowering oak-based clove notes in front of a short finish.',
#  "From vines planted in 1955, this is a rose-tinted Pinot with a woven, integrated bouquet of toast, mineral and berry fruits. There's more Burgundian character here than New World, so it pours on the cerebral scents and flavors of tea, rose hip, strawberry and raspberry. Reserved in style, but good to drink now and over the next few years. If $100 seems like a lot to spend on Argentinean Pinot, you should try to give this a taste at some point; you may be convinced otherwise.",
#  'Some winemakers have a special feel for Pinot Noir, and Michael Stevenson, winemaker for Elizabeth Chambers, has earned a place among those select few. Previously known as Panther Creek, the winery has been re-branded and re-imagined under the current owners. This deliberate, controlled single vineyard effort punches through with a concentrated mix of plum, rhubarb and cherry fruit, showing exceptional grip, balance and length.',
#  'This shows real varietal character with spicy peaches-and-cream flavors and a nice vein of smoky oak, and a honeyed, crisp finish.',
#  'The sweetest style of Madeira still has that wonderful burnt acidity that keeps it from being cloying. So while there is an initial toffee character, the wine then tightens up with orange marmalade and an intense acidity. Drink this beautiful wine now.',
#  'Aromas of white spring flower, oak-driven vanilla and a whiff of white stone fruit lead the nose. The oak sensations follow through the somewhat lean palate, along with pear and a confectionery note. It closes on a note of bitter almond.',
#  'Made with organically farmed grapes, this simple, rustic rosato conveys aromas of red berry, game and a whiff of cellar must. The palate offers crushed wild cherry alongside zesty acidity.',
#  'While ripe on the nose with scents of juicy red cherries, mocha chocolate and Graham cracker crumbs, this soft, light-bodied Pinot Noir gains a slightly rustic edge on the midpalate with hints of fall foliage and a soft, furry coating of tannins on the finish.',
#  "While restrained on the nose, there's plenty of zesty apple, lemon and pear on the palate of this off-dry Riesling. It's an elegant yet quaffable wine with a brisk, crystalline finish. Drink now.",
#  'Named after the stone blocks or menhirs which are a part of the Tannat vineyard, this a ripe, open and fruity wine. The Merlot does its job of softening the firm tannins of the Tannat and the blend gives a generous wine that has hints of the wood aging along with spice and acidity. Drink now.',
#  "Ignore its generic Oregon AVA—this is King Estate's top wine, a rich reserve-level Pinot Noir redolent with Asian spices, saffron, cumin and more. Nuances of dusty cocoa powder lead into a thrilling wine with a spine of steel, focusing its ripe, fleshy fruit through a long, cellar-worthy finish.",
#  'Raisin and baked plum aromas set the stage for a somewhat flat-feeling palate. Plum and berry aromas are chunky and finish soft, with low acidity and not a lot of pop.',
#  'Hints of sweet pastry introduce this bright, summery Merlot sparkling. Fun and fizzy, it fills the palate with rich, creamy mousse and sweet-tart strawberry-yogurt flavor.',
#  'Best on the nose, but sharp and narrow as can be on the palate. Cranberry and sour cherry flavors dominate, while the finish is astringent. No amount of swirling and saving is going help it much.',
#  'Crisp and fresh aromas of lime sorbet and iced apple flesh greet the nose on this Riboli family bottling. The palate is steely and bright, with Anjou pear flesh, a bit of smoke and some red-apple ripeness.',
#  ...]

# %%
X_train[70010]
# Out:
# 'Silky yet slightly grippy, this is a mineral-driven wine, with violet and spicy cardamom aromas atop bright, vibrant swathes of cherry and wild strawberry. This vineyard is where Joseph Swan himself first planted Pinot Noir, it retains all the promise and greatness of his initial discovery of this magical place along the Laguna Ridge.'

# %%
len(X_test)
# Out:
# 30244

# %%
#at this point, I'm not sure if we should run CountVectorizer on the test BEOFRE or AFTER splitting
#I'm going to go with after
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer()

# %%
X_train_counts = vect.fit_transform(X_train)

# %%
X_train_counts.shape
# Out:
# (90731, 27432)

# %%
#let's examine our data
vect.get_feature_names()
# Out:
# ['000',
#  '008',
#  '01',
#  '02',
#  '03',
#  '030',
#  '04',
#  '04s',
#  '05',
#  '056',
#  '06',
#  '061',
#  '064',
#  '07',
#  '07s',
#  '08',
#  '080',
#  '08s',
#  '09',
#  '093',
#  '09s',
#  '10',
#  '100',
#  '100th',
#  '101',
#  '1016',
#  '103',
#  '104',
#  '106',
#  '107th',
#  '108',
#  '10th',
#  '11',
#  '110',
#  '111',
#  '112',
#  '114',
#  '115',
#  '116',
#  '1194',
#  '11th',
#  '12',
#  '120',
#  '1200',
#  '122',
#  '125',
#  '1252',
#  '126',
#  '128',
#  '1290',
#  '12g',
#  '12th',
#  '13',
#  '130',
#  '130th',
#  '132',
#  '133',
#  '134',
#  '135',
#  '136',
#  '137',
#  '1375',
#  '1396',
#  '13g',
#  '13th',
#  '14',
#  '140',
#  '1429',
#  '146',
#  '147',
#  '14g',
#  '14th',
#  '15',
#  '150',
#  '1500',
#  '150th',
#  '154',
#  '155g',
#  '159g',
#  '15g',
#  '15s',
#  '15th',
#  '16',
#  '160',
#  '1600',
#  '1607',
#  '160g',
#  '161',
#  '1610',
#  '1628',
#  '164',
#  '1649',
#  '165',
#  '1667',
#  '1690',
#  '1692',
#  '16g',
#  '16th',
#  '17',
#  '170',
#  '1700s',
#  '170g',
#  '171',
#  '172',
#  '1737',
#  '1740',
#  '1744',
#  '175',
#  '1756',
#  '1759',
#  '177',
#  '1772',
#  '1780',
#  '1787',
#  '1789',
#  '179',
#  '17th',
#  '18',
#  '180',
#  '1800',
#  '1800s',
#  '1806',
#  '1811',
#  '1819',
#  '1820s',
#  '1829',
#  '183',
#  '1834',
#  '1835',
#  '1839',
#  '1843',
#  '1844',
#  '1847',
#  '1850',
#  '1850s',
#  '1851',
#  '1853',
#  '1855',
#  '1856',
#  '1858',
#  '1860s',
#  '1864',
#  '1865',
#  '1868',
#  '1869',
#  '187',
#  '1870',
#  '1873',
#  '1875',
#  '1877',
#  '1878',
#  '187ml',
#  '1881',
#  '1882',
#  '1889',
#  '1890',
#  '1890s',
#  '1892',
#  '1893',
#  '1895',
#  '189g',
#  '18th',
#  '19',
#  '1900',
#  '1901',
#  '1902',
#  '1903',
#  '1904',
#  '1905',
#  '1908',
#  '1909',
#  '191',
#  '1910',
#  '1912',
#  '1913',
#  '1914',
#  '1915',
#  '1917',
#  '1918',
#  '1919',
#  '1920',
#  '1920s',
#  '1922',
#  '1925',
#  '1926',
#  '1930',
#  '1930s',
#  '1933',
#  '1934',
#  '1935',
#  '1936',
#  '1937',
#  '1939',
#  '1940s',
#  '1946',
#  '1947',
#  '1948',
#  '194g',
#  '1950',
#  '1950s',
#  '1952',
#  '1953',
#  '1955',
#  '1956',
#  '1958',
#  '1959',
#  '196',
#  '1960',
#  '1960s',
#  '1962',
#  '1964',
#  '1965',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1970s',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '198',
#  '1980',
#  '1980s',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1990s',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '1999s',
#  '19th',
#  '1st',
#  '1ère',
#  '20',
#  '200',
#  '2000',
#  '2000s',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2004s',
#  '2005',
#  '2005s',
#  '2006',
#  '2006s',
#  '2007',
#  '2007s',
#  '2008',
#  '2008s',
#  '2009',
#  '2009s',
#  '2010',
#  '2010s',
#  '2011',
#  '2011s',
#  '2012',
#  '2012s',
#  '2013',
#  '2013s',
#  '2014',
#  '2014s',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '20206',
#  '2020s',
#  '2021',
#  '2022',
#  '2023',
#  '20230',
#  '2024',
#  '2025',
#  '2026',
#  '2027',
#  '2028',
#  '2029',
#  '2030',
#  '2031',
#  '2032',
#  '2033',
#  '2034',
#  '2035',
#  '2036',
#  '2037',
#  '2038',
#  '2040',
#  '2041',
#  '2042',
#  '2043',
#  '2045',
#  '2048',
#  '2050',
#  '2053',
#  '20g',
#  '20th',
#  '21',
#  '210',
#  '21st',
#  '22',
#  '220',
#  '222',
#  '223',
#  '225',
#  '227',
#  '22g',
#  '23',
#  '230',
#  '233',
#  '235',
#  '239',
#  '23g',
#  '24',
#  '240',
#  '244',
#  '245',
#  '246',
#  '25',
#  '250',
#  '255',
#  '25g',
#  '25th',
#  '26',
#  '260',
#  '263',
#  '266',
#  '26g',
#  '27',
#  '275',
#  '28',
#  '280',
#  '29',
#  '290',
#  '2923',
#  '2936',
#  '296',
#  '2a',
#  '2g',
#  '2l',
#  '30',
#  '300',
#  '305',
#  '30g',
#  '30th',
#  '31',
#  '315',
#  '319',
#  '32',
#  '325',
#  '325th',
#  '329',
#  '33',
#  '336',
#  '337',
#  '33rd',
#  '34',
#  '35',
#  '350',
#  '356',
#  '35th',
#  '36',
#  '360',
#  '37',
#  '370',
#  '375',
#  '375ml',
#  '38',
#  '380',
#  '387',
#  '389',
#  '39',
#  '398',
#  '3bb',
#  '3l',
#  '3m',
#  '3rd',
#  '3½',
#  '40',
#  '400',
#  '407',
#  '40g',
#  '40th',
#  '41',
#  '41st',
#  '42',
#  '420',
#  '422',
#  '424',
#  '43',
#  '44',
#  '440',
#  '45',
#  '450',
#  '45th',
#  '46',
#  '460',
#  '47',
#  '470',
#  '47g',
#  '48',
#  '49',
#  '4g',
#  '4th',
#  '50',
#  '500',
#  '500l',
#  '500th',
#  '50g',
#  '50th',
#  '51',
#  '52',
#  '525',
#  '53',
#  '54',
#  '54g',
#  '55',
#  '550',
#  '554',
#  '559',
#  '56',
#  '57',
#  '576',
#  '58',
#  '587',
#  '59',
#  '5g',
#  '60',
#  '600',
#  '606',
#  '60g',
#  '60th',
#  '61',
#  '62',
#  '63',
#  '64',
#  '65',
#  '650',
#  '66',
#  '663',
#  '666',
#  '667',
#  '67',
#  '68',
#  '685',
#  '69',
#  '690',
#  '6g',
#  '6th',
#  '70',
#  '700',
#  '707',
#  '70g',
#  '70s',
#  '71',
#  '72',
#  '7200',
#  '728',
#  '73',
#  '731',
#  '74',
#  '75',
#  '750',
#  '76',
#  '77',
#  '772',
#  '777',
#  '78',
#  '79',
#  '7up',
#  '7º',
#  '80',
#  '800',
#  '800th',
#  '80s',
#  '80th',
#  '81',
#  '82',
#  '828',
#  '83',
#  '84',
#  '843',
#  '84s',
#  '85',
#  '850',
#  '86',
#  '869',
#  '87',
#  '875',
#  '88',
#  '89',
#  '8g',
#  '8th',
#  '90',
#  '900',
#  '90s',
#  '90th',
#  '91',
#  '913',
#  '92',
#  '93',
#  '94',
#  '940',
#  '95',
#  '950',
#  '96',
#  '961',
#  '97',
#  '975',
#  '98',
#  '984',
#  '98s',
#  '99',
#  '995',
#  '99s',
#  '9g',
#  'a1611',
#  'a307',
#  'aacacia',
#  'aand',
#  'aaron',
#  'abacela',
#  'abadal',
#  'abadia',
#  'abandon',
#  'abandoned',
#  'abate',
#  'abbazia',
#  'abbey',
#  'abbott',
#  'abbreviated',
#  'abc',
#  'abeille',
#  'abeilles',
#  'abeja',
#  'abel',
#  'abele',
#  'abelis',
#  'abelé',
#  'abernathy',
#  'abeyance',
#  'abide',
#  'abiding',
#  'abilio',
#  'abilities',
#  'ability',
#  'abiouness',
#  'able',
#  'ably',
#  'abnormal',
#  'abnormally',
#  'aboard',
#  'abondante',
#  'aboriginal',
#  'abound',
#  'abounds',
#  'abouriou',
#  'about',
#  'abovde',
#  'above',
#  'abraham',
#  'abrasive',
#  'abrasiveness',
#  'abraxas',
#  'abreu',
#  'abrigo',
#  'abroad',
#  'abrupt',
#  'abruptly',
#  'abruptness',
#  'abruzzo',
#  'absence',
#  'absense',
#  'absent',
#  'absinthe',
#  'absolute',
#  'absolutely',
#  'absorb',
#  'absorbed',
#  'absorbingly',
#  'absurd',
#  'absurdly',
#  'abtsberg',
#  'abundance',
#  'abundant',
#  'abundantly',
#  'abupt',
#  'abused',
#  'abuts',
#  'abuzz',
#  'abv',
#  'ac',
#  'acacia',
#  'academic',
#  'acai',
#  'acccessible',
#  'accelerate',
#  'accelerates',
#  'accent',
#  'accented',
#  'accenting',
#  'accents',
#  'accentuate',
#  'accentuated',
#  'accentuates',
#  'accentuating',
#  'acceptability',
#  'acceptable',
#  'acceptance',
#  'accesible',
#  'access',
#  'accessable',
#  'accesses',
#  'accessibile',
#  'accessibility',
#  'accessible',
#  'accessibly',
#  'accessorized',
#  'accetnes',
#  'accident',
#  'accidental',
#  'acclaimed',
#  'accolade',
#  'accolades',
#  'accommodates',
#  'accompained',
#  'accompanied',
#  'accompanies',
#  'accompaniment',
#  'accompaniments',
#  'accompany',
#  'accompanying',
#  'accomplish',
#  'accomplished',
#  'accomplishes',
#  'accomplishment',
#  'accord',
#  'accordance',
#  'according',
#  'accordingly',
#  'accordini',
#  'accordion',
#  'account',
#  'accountant',
#  'accounted',
#  'accounting',
#  'accounts',
#  'accumulate',
#  'accumulating',
#  'accurate',
#  'accurately',
#  'accused',
#  'accustomed',
#  'ace',
#  'aces',
#  'acetic',
#  'acetone',
#  'achaval',
#  'acheived',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achievements',
#  'achieves',
#  'achieving',
#  'aching',
#  'achingly',
#  'achleiten',
#  'aciar',
#  'acid',
#  'acidhounds',
#  'acidic',
#  'acidically',
#  'acidicy',
#  'acididty',
#  'acidification',
#  'acidified',
#  'acidify',
#  'acidity',
#  'acidiy',
#  'acids',
#  'acidty',
#  'aciidty',
#  'aciprestes',
#  'acitity',
#  'ackhurst',
#  'acknowledged',
#  'acknowledges',
#  'acohol',
#  'aconcagua',
#  'acorn',
#  'acorns',
#  'acorny',
#  'acquaintance',
#  'acquavigna',
#  'acqui',
#  'acquire',
#  'acquired',
#  'acquires',
#  'acquiring',
#  'acquit',
#  'acquits',
#  'acquitted',
#  'acre',
#  'acreage',
#  'acres',
#  'acrid',
#  'acrobat',
#  'acrobatics',
#  'across',
#  'act',
#  'acted',
#  'acting',
#  'action',
#  'active',
#  'actively',
#  'activity',
#  'actor',
#  'actress',
#  'acts',
#  'actual',
#  'actuality',
#  'actually',
#  'acute',
#  'acutely',
#  'ad',
#  'adage',
#  'adam',
#  'adamant',
#  'adami',
#  'adams',
#  'adaptability',
#  'adaptable',
#  'adaptation',
#  'add',
#  'addamo',
#  'added',
#  'addictive',
#  'addictively',
#  'addicts',
#  'adding',
#  'addition',
#  'additional',
#  'additionally',
#  'additions',
#  'additives',
#  'address',
#  'adds',
#  'ade',
#  'adega',
#  'adelaida',
#  'adelaide',
#  'adele',
#  'adelsheim',
#  'adelsheims',
#  'adept',
#  'adequate',
#  'adequately',
#  'adhere',
#  'adherence',
#  'adheres',
#  'adhesive',
#  'adige',
#  'adjacent',
#  'adjectives',
#  'adjoins',
#  'adjunct',
#  'adjusted',
#  'administered',
#  'admirable',
#  'admirably',
#  'admiral',
#  'admiration',
#  'admire',
#  'admired',
#  'admirers',
#  'admission',
#  'admit',
#  'admitted',
#  'admittedly',
#  'admitting',
#  'admixture',
#  'ado',
#  'adolescent',
#  'adolph',
#  'adopted',
#  'adopting',
#  'adopts',
#  'adore',
#  'adored',
#  'adoring',
#  'adorn',
#  'adorned',
#  'adorning',
#  'adornments',
#  'adorns',
#  'adour',
#  'adquate',
#  'adriana',
#  'adrianna',
#  'adriano',
#  'adriatic',
#  'adrienne',
#  'adroitly',
#  'adult',
#  'adults',
#  'advance',
#  'advanced',
#  'advancement',
#  'advances',
#  'advantage',
#  'adventure',
#  'adventurers',
#  'adventurous',
#  'advertised',
#  'advertisement',
#  'advertises',
#  'advertising',
#  'advice',
#  'advisable',
#  'advised',
#  'advocacy',
#  'adènzia',
#  'adèo',
#  'aegean',
#  'aegerter',
#  'aeolia',
#  'aerate',
#  'aerated',
#  'aerates',
#  'aerating',
#  'aeration',
#  'aerator',
#  'aerosmith',
#  'aerospace',
#  'aesthetic',
#  'aesthetics',
#  'afar',
#  'afertaste',
#  'affable',
#  'affair',
#  'affect',
#  'affectation',
#  'affected',
#  'affecting',
#  'affection',
#  'affects',
#  'afficionadoes',
#  'afficionados',
#  'affile',
#  'affiliated',
#  'affinity',
#  'affirm',
#  'affixed',
#  'afflicted',
#  'afforable',
#  'afford',
#  'affordability',
#  'affordable',
#  'affordably',
#  'affording',
#  'affords',
#  'affront',
#  'aficianados',
#  'aficionados',
#  'afield',
#  'afloat',
#  'aflutter',
#  'afoot',
#  'aforementioned',
#  'afoul',
#  'afraid',
#  'afresh',
#  'africa',
#  'african',
#  'africans',
#  'afrikaans',
#  'after',
#  'afteratste',
#  'afterburn',
#  'afterburners',
#  'afterflavors',
#  'aftermath',
#  'afternoon',
#  'afternoons',
#  'afternote',
#  'afternotes',
#  'aftershock',
#  'aftershocks',
#  'aftertaste',
#  'aftertastes',
#  'afterthought',
#  'afterthoughts',
#  'aftertones',
#  'afterward',
#  'afterwards',
#  'again',
#  'against',
#  'agassac',
#  'agate',
#  'agave',
#  'age',
#  'ageabiity',
#  'ageability',
#  'ageabilty',
#  'ageable',
#  'agebrush',
#  'aged',
#  'ageing',
#  'agen',
#  'agenda',
#  'agent',
#  'ager',
#  'ages',
#  'ageworthiness',
#  'ageworthy',
#  'aggression',
#  'aggressive',
#  'aggressively',
#  'aggressiveness',
#  'agile',
#  'agility',
#  'aging',
#  'agiorgitiko',
#  'agiorgitkio',
#  'agiorgitko',
#  'aglianico',
#  'agng',
#  'ago',
#  'agostina',
#  'agoston',
#  'agrapart',
#  'agree',
#  'agreeability',
#  'agreeable',
#  'agreeably',
#  'agrelo',
#  'agressive',
#  'agressively',
#  'agriculture',
#  'agrigento',
#  'agro',
#  'agrocert',
#  'agua',
#  'agueira',
#  'aguia',
#  'aguieira',
#  'agustin',
#  'ah',
#  'ahead',
#  'ahi',
#  'ahn',
#  'ahoy',
#  'ai',
#  'aia',
#  'aid',
#  'aided',
#  'aidil',
#  'aiding',
#  'aids',
#  'aiken',
#  'aim',
#  'aimed',
#  'aiming',
#  'aimless',
#  'aimlessly',
#  'aims',
#  'ain',
#  'aiolo',
#  'air',
#  'airborne',
#  'aired',
#  'airen',
#  'airfield',
#  'airiness',
#  'airing',
#  'airs',
#  'airtime',
#  ...]

# %%
#make a list of the numerical feature names
stop_list = vect.get_feature_names()
stop_list = stop_list[:540]

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (90731, 27432)

# %%
type(X_train_tfidf)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
X_train_tfidf
# Out:
# <90731x27432 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3143726 stored elements in Compressed Sparse Row format>

# %%
#now we will explore turning the sparse matrix from the TF-IDF transform into a dataframe.
#If we can do this, we can then create a new dataframe with all other wine values that also includes the TF_IDF
#we can then do this on all the data, and then split the data into training and testing data.
TF = pd.DataFrame({'TF_IDF': list(X_train_tfidf)})

# %%
TF.head()
# Out:
#                                               TF_IDF
# 0    (0, 1319)\t0.17940045025301316\n  (0, 25809)...
# 1    (0, 16724)\t0.032516835550230085\n  (0, 1348...
# 2    (0, 16724)\t0.04859509521515342\n  (0, 1348)...
# 3    (0, 16724)\t0.085053971917573\n  (0, 1348)\t...
# 4    (0, 16724)\t0.11281086063920866\n  (0, 12702...

# %% [markdown]
# Above, we can see casting the sparse matrix to a list allows it to be added to a dataframe. We will next have to test if we can then pass this into an ML algorithm

# %%
y_train
# Out:
# array([85, 92, 86, ..., 88, 87, 92], dtype=int64)

# %%
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
X_t2 = TF['TF_IDF'].tolist()
X_t2 = np.array(X_t2).reshape(-1,1)

# %%
import scipy.sparse as sps

# %%
sps.coo_matrix(TF.TF_IDF.values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-bdf6c7e8d758> in <module>()
# ----> 1 sps.coo_matrix(TF.TF_IDF.values)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\scipy\sparse\coo.py in __init__(self, arg1, shape, dtype, copy)
#     182                     self.shape = M.shape
#     183
# --> 184                 self.row, self.col = M.nonzero()
#     185                 self.data = M[self.row, self.col]
#     186                 self.has_canonical_format = True
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\scipy\sparse\base.py in __bool__(self)
#     256             return self.nnz != 0
#     257         else:
# --> 258             raise ValueError("The truth value of an array with more than one "
#     259                              "element is ambiguous. Use a.any() or a.all().")
#     260     __nonzero__ = __bool__
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all().

# %%
X_t3 = scipy.sparse.csr_matrix(TF['TF_IDF'].values.T)
X_t3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-ab2452acbb06> in <module>()
# ----> 1 X_t3 = scipy.sparse.csr_matrix(TF['TF_IDF'].values.T)
#       2 X_t3
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\scipy\sparse\compressed.py in __init__(self, arg1, shape, dtype, copy)
#      77                         self.format)
#      78             from .coo import coo_matrix
# ---> 79             self._set_self(self.__class__(coo_matrix(arg1, dtype=dtype)))
#      80
#      81         # Read matrix dimensions given, if any
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\scipy\sparse\coo.py in __init__(self, arg1, shape, dtype, copy)
#     182                     self.shape = M.shape
#     183
# --> 184                 self.row, self.col = M.nonzero()
#     185                 self.data = M[self.row, self.col]
#     186                 self.has_canonical_format = True
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\scipy\sparse\base.py in __bool__(self)
#     256             return self.nnz != 0
#     257         else:
# --> 258             raise ValueError("The truth value of an array with more than one "
#     259                              "element is ambiguous. Use a.any() or a.all().")
#     260     __nonzero__ = __bool__
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all().

# %%
X_t2
# Out:
# array([[<1x27432 sparse matrix of type '<class 'numpy.float64'>'
# 	with 38 stored elements in Compressed Sparse Row format>],
#        [<1x27432 sparse matrix of type '<class 'numpy.float64'>'
# 	with 42 stored elements in Compressed Sparse Row format>],
#        [<1x27432 sparse matrix of type '<class 'numpy.float64'>'
# 	with 36 stored elements in Compressed Sparse Row format>],
#        ...,
#        [<1x27432 sparse matrix of type '<class 'numpy.float64'>'
# 	with 38 stored elements in Compressed Sparse Row format>],
#        [<1x27432 sparse matrix of type '<class 'numpy.float64'>'
# 	with 41 stored elements in Compressed Sparse Row format>],
#        [<1x27432 sparse matrix of type '<class 'numpy.float64'>'
# 	with 51 stored elements in Compressed Sparse Row format>]], dtype=object)

# %%
mnb2 = MultinomialNB().fit(X_t2, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-16dca36dab58> in <module>()
#       1
# ----> 2 mnb2 = MultinomialNB().fit(X_t2, y_train)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     577             Returns self.
#     578         """
# --> 579         X, y = check_X_y(X, y, 'csr')
#     580         _, n_features = X.shape
#     581
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: setting an array element with a sequence.

# %%
print(f"Training Data Score: {mnb.score(X_train_tfidf, y_train)}")
# Out:
# Training Data Score: 0.27863684958834356

# %% [markdown]
# Ok, so we can see here that our Naive Bayes model using only the descriptions does not product a good predictive model. We should next test a Support Vector Machine model.

# %%
mnb.predict(X_train_tfidf[80000])
# Out:
# array([87], dtype=int64)

# %%
y_train[80000]
# Out:
# 90

# %%
#to run a prediction on the test data, we will first need to count vectorize, transform, and tfidf
#transform the X_test data

# %%
from sklearn.linear_model import SGDClassifier
sgdc = SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=42, max_iter=5, tol=None).fit(X_train_tfidf, y_train)

# %%
print(f"Training Data Score: {sgdc.score(X_train_tfidf, y_train)}")
# Out:
# Training Data Score: 0.4703133438405837

# %%
print(sgdc.predict(X_train_tfidf[70010]))
print(y_train[70010])
# Out:
# [95]
# 95

# %%
#now let's try doing the countvectorizer on our original data with n-grams and removing extraneous words
X = text_df.description.tolist()
y = text_df.points.values
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
vect = CountVectorizer(ngram_range=(1,3), stop_words=stop_list)

# %%
X_train_counts = vect.fit_transform(X_train)

# %%
vect.get_feature_names()
# Out:
# ['aacacia',
#  'aacacia flower',
#  'aand',
#  'aand tingling',
#  'aaron',
#  'aaron jackson',
#  'aaron pott',
#  'aaron walker',
#  'abacela',
#  'abacela albariño',
#  'abacela dedication',
#  'abacela in',
#  'abacela makes',
#  'abacela tenth',
#  'abacela wines',
#  'abadal',
#  'abadal label',
#  'abadal maker',
#  'abadia',
#  'abadia retuerta',
#  'abandon',
#  'abandon bristling',
#  'abandon it',
#  'abandon of',
#  'abandon stewed',
#  'abandon yourself',
#  'abandoned',
#  'abandoned grillo',
#  'abandoned thus',
#  'abate',
#  'abate fetel',
#  'abate subzone',
#  'abbazia',
#  'abbazia di',
#  'abbey',
#  'abbey has',
#  'abbey in',
#  'abbey of',
#  'abbey ridge',
#  'abbey ruins',
#  'abbey which',
#  'abbey would',
#  'abbott',
#  'abbott cajoles',
#  'abbott chalone',
#  'abbott ex',
#  'abbott has',
#  'abbott in',
#  'abbott sources',
#  'abbreviated',
#  'abbreviated finish',
#  'abc',
#  'abc production',
#  'abeille',
#  'abeille family',
#  'abeilles',
#  'abeilles is',
#  'abeja',
#  'abeja chardonnays',
#  'abeja estate',
#  'abeja jumps',
#  'abeja kicks',
#  'abeja main',
#  'abeja style',
#  'abeja winemaker',
#  'abeja wines',
#  'abel',
#  'abel clone',
#  'abele',
#  'abele it',
#  'abelis',
#  'abelis carthago',
#  'abelé',
#  'abelé has',
#  'abelé remains',
#  'abernathy',
#  'abernathy vineyard',
#  'abeyance',
#  'abeyance the',
#  'abide',
#  'abiding',
#  'abiding freshness',
#  'abilio',
#  'abilio tavares',
#  'abilities',
#  'abilities of',
#  'abilities with',
#  'ability',
#  'ability drink',
#  'ability for',
#  'ability in',
#  'ability is',
#  'ability it',
#  'ability of',
#  'ability this',
#  'ability to',
#  'ability try',
#  'abiouness',
#  'able',
#  'able and',
#  'able interesting',
#  'able to',
#  'ably',
#  'ably assisted',
#  'ably balances',
#  'ably combining',
#  'ably conceal',
#  'ably frame',
#  'ably marries',
#  'ably marrying',
#  'ably partner',
#  'ably reflect',
#  'ably reflecting',
#  'abnormal',
#  'abnormal aromas',
#  'abnormal by',
#  'abnormal for',
#  'abnormally',
#  'abnormally high',
#  'aboard',
#  'aboard minerally',
#  'abondante',
#  'abondante is',
#  'aboriginal',
#  'aboriginal for',
#  'abound',
#  'abound accented',
#  'abound accenting',
#  'abound against',
#  'abound along',
#  'abound and',
#  'abound as',
#  'abound boysenberry',
#  'abound bringing',
#  'abound cassis',
#  'abound coming',
#  'abound earth',
#  'abound especially',
#  'abound flavor',
#  'abound from',
#  'abound glimmers',
#  'abound here',
#  'abound if',
#  'abound immediately',
#  'abound in',
#  'abound it',
#  'abound loading',
#  'abound luscious',
#  'abound making',
#  'abound on',
#  'abound pushing',
#  'abound soaked',
#  'abound the',
#  'abound there',
#  'abound throughout',
#  'abound tinged',
#  'abound underscored',
#  'abound velvety',
#  'abound while',
#  'abound with',
#  'abound wrapped',
#  'abounds',
#  'abounds but',
#  'abounds in',
#  'abounds on',
#  'abounds the',
#  'abounds throughout',
#  'abounds with',
#  'abounds wrapped',
#  'abouriou',
#  'abouriou and',
#  'abouriou as',
#  'abouriou full',
#  'abouriou grape',
#  'abouriou is',
#  'abouriou which',
#  'about',
#  'about acid',
#  'about acidity',
#  'about acres',
#  'about affordable',
#  'about all',
#  'about an',
#  'about analyzing',
#  'about and',
#  'about any',
#  'about anything',
#  'about anywhere',
#  'about argentinean',
#  'about aromas',
#  'about aromatic',
#  'about arresting',
#  'about as',
#  'about at',
#  'about average',
#  'about balance',
#  'about before',
#  'about being',
#  'about berry',
#  'about black',
#  'about blackberries',
#  'about blackberry',
#  'about blue',
#  'about bottle',
#  'about bright',
#  'about brightness',
#  'about brisk',
#  'about but',
#  'about buttered',
#  'about by',
#  'about cab',
#  'about california',
#  'about canned',
#  'about carbonic',
#  'about casa',
#  'about cases',
#  'about catalonian',
#  'about century',
#  'about chalky',
#  'about chardonnay',
#  'about cherries',
#  'about cherry',
#  'about chocolate',
#  'about chunky',
#  'about cinnamon',
#  'about citrus',
#  'about class',
#  'about clean',
#  'about coastal',
#  'about coconut',
#  'about coffee',
#  'about cola',
#  'about color',
#  'about complexity',
#  'about composed',
#  'about consistency',
#  'about crisp',
#  'about crispness',
#  'about crushed',
#  'about currants',
#  'about cut',
#  'about dark',
#  'about deep',
#  'about delicacy',
#  'about delicious',
#  'about deliciously',
#  'about density',
#  'about done',
#  'about dried',
#  'about drink',
#  'about drinking',
#  'about driving',
#  'about dry',
#  'about each',
#  'about earth',
#  'about easy',
#  'about eight',
#  'about elegance',
#  'about equal',
#  'about equally',
#  'about eve',
#  'about every',
#  'about everything',
#  'about exotic',
#  'about expressing',
#  'about extract',
#  'about extreme',
#  'about exuberant',
#  'about fascinating',
#  'about feel',
#  'about feels',
#  'about feet',
#  'about fine',
#  'about finesse',
#  'about finessed',
#  'about finish',
#  'about firmness',
#  'about five',
#  'about flashy',
#  'about flavor',
#  'about flavorwise',
#  'about food',
#  'about forested',
#  'about forward',
#  'about four',
#  'about foxen',
#  'about fresh',
#  'about freshness',
#  'about from',
#  'about fruit',
#  'about fruitiness',
#  'about full',
#  'about gewürztraminer',
#  'about ginger',
#  'about giving',
#  'about good',
#  'about granite',
#  'about grapefruit',
#  'about great',
#  'about green',
#  'about grenache',
#  'about gripping',
#  'about gritty',
#  'about half',
#  'about halfway',
#  'about heat',
#  'about hedonistic',
#  'about herbaceous',
#  'about hiding',
#  'about high',
#  'about how',
#  'about howell',
#  'about hummus',
#  'about immediate',
#  'about impact',
#  'about imported',
#  'about impressing',
#  'about in',
#  'about information',
#  'about integration',
#  'about intense',
#  'about is',
#  'about it',
#  'about its',
#  'about jammy',
#  'about joy',
#  'about juicy',
#  'about keefer',
#  'about late',
#  'about lemon',
#  'about licorice',
#  'about like',
#  'about loire',
#  'about long',
#  'about magnetic',
#  'about making',
#  'about malbec',
#  'about meaty',
#  'about medium',
#  'about merlot',
#  'about mid',
#  'about midway',
#  'about miles',
#  'about mineral',
#  'about minerality',
#  'about minerally',
#  'about minerals',
#  'about minutes',
#  'about mocha',
#  'about monster',
#  'about months',
#  'about more',
#  'about mosel',
#  'about mouth',
#  'about mushroom',
#  'about napa',
#  'about new',
#  'about nose',
#  'about nuance',
#  'about oak',
#  'about oakville',
#  'about of',
#  'about one',
#  'about opening',
#  'about others',
#  'about overt',
#  'about peppered',
#  'about perfect',
#  'about perfumed',
#  'about perfumes',
#  'about petit',
#  'about petite',
#  'about pie',
#  'about pinot',
#  'about pizza',
#  'about plum',
#  'about polish',
#  'about potential',
#  'about power',
#  'about price',
#  'about primary',
#  'about producing',
#  'about pure',
#  'about purity',
#  'about purple',
#  'about quality',
#  'about quarter',
#  'about raspberry',
#  'about raw',
#  'about reached',
#  'about ready',
#  'about red',
#  'about refreshment',
#  'about residual',
#  'about resiny',
#  'about restrained',
#  'about retasted',
#  'about ribera',
#  'about rich',
#  'about right',
#  'about ripe',
#  'about ripeness',
#  'about ripped',
#  'about roasted',
#  'about robust',
#  'about sangiovese',
#  'about sauv',
#  'about second',
#  'about secondary',
#  'about serious',
#  'about serving',
#  'about sharp',
#  'about sheer',
#  'about simple',
#  'about six',
#  'about size',
#  'about sliced',
#  'about slight',
#  'about small',
#  'about smooth',
#  'about soft',
#  'about soil',
#  'about sophistication',
#  'about sourdough',
#  'about spice',
#  'about spicy',
#  'about spot',
#  'about stewed',
#  'about still',
#  'about stone',
#  'about stormy',
#  'about strawberries',
#  'about strawberry',
#  'about structure',
#  'about sublimis',
#  'about subtle',
#  'about subtlety',
#  'about such',
#  'about summer',
#  'about summertime',
#  'about sweet',
#  'about sweetness',
#  'about syrah',
#  'about tangy',
#  'about tannic',
#  'about tart',
#  'about technically',
#  'about tense',
#  'about tension',
#  'about tenuta',
#  'about terroir',
#  'about texture',
#  'about that',
#  'about the',
#  'about their',
#  'about them',
#  'about these',
#  'about third',
#  'about this',
#  'about three',
#  'about to',
#  'about ton',
#  'about toro',
#  'about total',
#  'about trying',
#  'about two',
#  'about underripe',
#  'about until',
#  'about upfront',
#  'about viognier',
#  'about waiting',
#  'about was',
#  'about washington',
#  'about wavy',
#  'about what',
#  'about where',
#  'about white',
#  'about whites',
#  'about wildflowers',
#  'about with',
#  'about wonderful',
#  'about wood',
#  'about year',
#  'about years',
#  'about yellow',
#  'about your',
#  'about zesty',
#  'about zinfandel',
#  'abovde',
#  'abovde enticing',
#  'above',
#  'above alexander',
#  'above all',
#  'above amazing',
#  'above ampuis',
#  'above an',
#  'above and',
#  'above angels',
#  'above annapolis',
#  'above appetizing',
#  'above around',
#  'above average',
#  'above balanced',
#  'above bed',
#  'above being',
#  'above black',
#  'above cadillac',
#  'above calistoga',
#  'above cambria',
#  'above carmel',
#  'above cerequio',
#  'above chunky',
#  'above château',
#  'above citrus',
#  'above concentrated',
#  'above cool',
#  'above core',
#  'above cornas',
#  'above corralitos',
#  'above cupertino',
#  'above descriptors',
#  'above earthy',
#  'above everything',
#  'above famed',
#  'above firm',
#  'above fort',
#  'above freestone',
#  'above fresh',
#  'above fruit',
#  'above gaillac',
#  'above generic',
#  'above heather',
#  'above in',
#  'above it',
#  'above its',
#  'above jamestown',
#  'above jolivet',
#  'above lake',
#  'above light',
#  'above limestone',
#  'above malibu',
#  'above many',
#  'above mareuil',
#  'above mere',
#  'above monterey',
#  'above most',
#  'above much',
#  'above napa',
#  'above neutral',
#  'above normal',
#  'above nose',
#  'above nuits',
#  'above oakville',
#  'above other',
#  'above palate',
#  'above peppery',
#  'above pinhão',
#  'above point',
#  'above power',
#  'above puligny',
#  'above rich',
#  'above ripe',
#  'above rutherford',
#  'above saint',
#  'above santenay',
#  'above savigny',
#  'above scents',
#  'above sea',
#  'above silicon',
#  'above simple',
#  'above sonoma',
#  'above st',
#  'above tart',
#  'above that',
#  'above the',
#  'above their',
#  'above thick',
#  'above this',
#  'above threshhold',
#  'above tight',
#  'above unacceptable',
#  'above vouvray',
#  'above water',
#  'above what',
#  'above where',
#  'above which',
#  'above wine',
#  'above with',
#  'abraham',
#  'abraham perold',
#  'abrasive',
#  'abrasive acidity',
#  'abrasive and',
#  'abrasive aromas',
#  'abrasive as',
#  'abrasive but',
#  'abrasive cherry',
#  'abrasive dark',
#  'abrasive drink',
#  'abrasive drying',
#  'abrasive even',
#  'abrasive finish',
#  'abrasive flavors',
#  'abrasive hard',
#  'abrasive in',
#  'abrasive mouthfeel',
#  'abrasive on',
#  'abrasive or',
#  'abrasive palate',
#  'abrasive plum',
#  'abrasive residual',
#  'abrasive rubbery',
#  'abrasive scour',
#  'abrasive scratchy',
#  'abrasive tannic',
#  'abrasive tannins',
#  'abrasive the',
#  'abrasive this',
#  'abrasive while',
#  'abrasive wine',
#  'abrasive with',
#  'abrasive wood',
#  'abrasive yet',
#  'abrasiveness',
#  'abrasiveness quick',
#  'abrasiveness that',
#  'abraxas',
#  'abraxas makes',
#  'abreu',
#  'abreu bello',
#  'abreu callado',
#  'abrigo',
#  'abrigo consistently',
#  'abroad',
#  'abroad it',
#  'abroad or',
#  'abrupt',
#  'abrupt and',
#  'abrupt astringent',
#  'abrupt bitter',
#  'abrupt but',
#  'abrupt dark',
#  'abrupt drink',
#  'abrupt drying',
#  'abrupt finish',
#  'abrupt hard',
#  'abrupt in',
#  'abrupt lean',
#  'abrupt marked',
#  'abrupt on',
#  'abrupt palate',
#  'abrupt raspy',
#  'abrupt raw',
#  'abrupt tangerine',
#  'abrupt tannic',
#  'abrupt tannins',
#  'abrupt with',
#  'abruptly',
#  'abruptly as',
#  'abruptly closing',
#  'abruptly drink',
#  'abruptly ends',
#  'abruptly hits',
#  'abruptly in',
#  'abruptly leaving',
#  'abruptly on',
#  'abruptly tannic',
#  'abruptly this',
#  'abruptly with',
#  'abruptness',
#  'abruptness dry',
#  'abruzzo',
#  'abruzzo and',
#  'abruzzo delivers',
#  'abruzzo in',
#  'abruzzo is',
#  'abruzzo made',
#  'abruzzo opens',
#  'abruzzo passerina',
#  'abruzzo region',
#  'abruzzo riserva',
#  'abruzzo should',
#  'abruzzo shows',
#  'abruzzo that',
#  'abruzzo this',
#  'abruzzo with',
#  'absence',
#  'absence of',
#  'absense',
#  'absense of',
#  'absent',
#  'absent acidity',
#  'absent are',
#  'absent the',
#  'absent there',
#  'absinthe',
#  'absinthe like',
#  'absolute',
#  'absolute and',
#  'absolute balance',
#  'absolute best',
#  'absolute concentration',
#  'absolute delight',
#  'absolute dryness',
#  'absolute elegance',
#  'absolute expert',
#  'absolute focus',
#  'absolute freshness',
#  'absolute fruitiness',
#  'absolute joy',
#  'absolute juiciness',
#  'absolute keeper',
#  'absolute pleasure',
#  'absolute power',
#  'absolute precision',
#  'absolute purity',
#  'absolute quality',
#  'absolute riot',
#  'absolute showstopper',
#  'absolute steal',
#  'absolute uncompromising',
#  'absolute varietal',
#  'absolute winner',
#  'absolutely',
#  'absolutely at',
#  'absolutely beautiful',
#  'absolutely best',
#  'absolutely black',
#  'absolutely bone',
#  'absolutely built',
#  'absolutely bursting',
#  'absolutely charming',
#  'absolutely classic',
#  'absolutely clean',
#  'absolutely convincing',
#  'absolutely dazzling',
#  'absolutely delicious',
#  'absolutely delightful',
#  'absolutely demands',
#  'absolutely dominates',
#  'absolutely dry',
#  'absolutely first',
#  'absolutely flavorful',
#  'absolutely fresh',
#  'absolutely full',
#  'absolutely gorgeous',
#  'absolutely hate',
#  'absolutely huge',
#  'absolutely immaculate',
#  'absolutely impeccable',
#  'absolutely irresistible',
#  'absolutely lip',
#  'absolutely loaded',
#  'absolutely love',
#  'absolutely lovely',
#  'absolutely massive',
#  'absolutely matters',
#  'absolutely mouth',
#  'absolutely must',
#  'absolutely natural',
#  'absolutely no',
#  'absolutely none',
#  'absolutely not',
#  'absolutely nothing',
#  'absolutely once',
#  'absolutely opaque',
#  'absolutely perfect',
#  'absolutely positively',
#  'absolutely pure',
#  'absolutely ready',
#  'absolutely refreshing',
#  'absolutely requires',
#  'absolutely seduces',
#  'absolutely smooth',
#  'absolutely straight',
#  'absolutely streamlined',
#  'absolutely stunning',
#  'absolutely tart',
#  'absolutely terrific',
#  'absolutely uncompromising',
#  'absolutely unruly',
#  'absolutely want',
#  'absolutely what',
#  'absolutely yummy',
#  'absorb',
#  'absorb all',
#  'absorb amplified',
#  'absorb it',
#  'absorb its',
#  'absorb massively',
#  'absorb more',
#  'absorb the',
#  'absorb them',
#  'absorb this',
#  'absorbed',
#  'absorbed and',
#  'absorbed best',
#  'absorbed by',
#  'absorbed in',
#  'absorbed into',
#  'absorbed new',
#  'absorbed smooth',
#  'absorbed too',
#  'absorbingly',
#  'absorbingly complex',
#  'absurd',
#  'absurd how',
#  'absurdly',
#  'absurdly low',
#  'absurdly priced',
#  'abtsberg',
#  'abtsberg superior',
#  'abundance',
#  'abundance all',
#  'abundance along',
#  'abundance alongside',
#  'abundance although',
#  'abundance and',
#  'abundance as',
#  'abundance beyond',
#  'abundance but',
#  'abundance caressed',
#  'abundance concentration',
#  'abundance drink',
#  'abundance ending',
#  'abundance followed',
#  'abundance here',
#  'abundance in',
#  'abundance initially',
#  'abundance is',
#  'abundance it',
#  'abundance its',
#  'abundance lightly',
#  'abundance of',
#  'abundance sets',
#  'abundance showing',
#  'abundance the',
#  'abundance with',
#  'abundant',
#  'abundant acidity',
#  'abundant and',
#  'abundant apple',
#  'abundant apricot',
#  'abundant aromas',
#  'abundant baking',
#  'abundant barrel',
#  'abundant black',
#  'abundant blue',
#  'abundant brambly',
#  'abundant but',
#  'abundant cedar',
#  'abundant cherry',
#  'abundant citrus',
#  'abundant coffee',
#  'abundant cranberry',
#  'abundant dark',
#  'abundant density',
#  'abundant fig',
#  'abundant flavors',
#  'abundant floral',
#  'abundant forest',
#  'abundant fresh',
#  'abundant freshness',
#  'abundant fruit',
#  'abundant green',
#  'abundant herb',
#  'abundant in',
#  'abundant juicy',
#  'abundant kiwi',
#  'abundant layered',
#  'abundant layers',
#  'abundant lees',
#  'abundant lemon',
#  'abundant lime',
#  'abundant lip',
#  'abundant mandarin',
#  'abundant melon',
#  'abundant mesquite',
#  'abundant milk',
#  'abundant minerality',
#  'abundant notes',
#  'abundant oak',
#  'abundant of',
#  'abundant olive',
#  'abundant on',
#  'abundant orange',
#  'abundant palate',
#  'abundant peach',
#  'abundant peaches',
#  'abundant pear',
#  'abundant plum',
#  'abundant raspberry',
#  'abundant red',
#  'abundant ripe',
#  'abundant rose',
#  'abundant savory',
#  'abundant smoked',
#  'abundant spice',
#  'abundant spices',
#  'abundant stone',
#  'abundant sweet',
#  'abundant tangerine',
#  'abundant tannins',
#  'abundant tart',
#  'abundant they',
#  'abundant toasty',
#  'abundant tropical',
#  'abundant umami',
#  'abundant vanilla',
#  'abundant with',
#  'abundant wood',
#  'abundant woodspice',
#  'abundant yellow',
#  'abundant yet',
#  'abundantly',
#  'abundantly elegant',
#  'abundantly floral',
#  'abundantly mouth',
#  'abundantly oaky',
#  'abundantly pear',
#  'abundantly plummy',
#  'abundantly proportioned',
#  'abundantly rich',
#  'abundantly ripe',
#  'abundantly tannic',
#  'abupt',
#  'abupt on',
#  'abused',
#  'abused here',
#  'abused style',
#  'abuts',
#  'abuts some',
#  'abuzz',
#  'abuzz in',
#  'abv',
#  'abv additional',
#  'abv and',
#  'abv bedell',
#  'abv bursting',
#  'abv but',
#  'abv drink',
#  'abv for',
#  'abv giving',
#  'abv heavyweight',
#  'abv instead',
#  'abv is',
#  'abv it',
#  'abv la',
#  'abv listed',
#  'abv means',
#  'abv one',
#  'abv really',
#  'abv savory',
#  'abv scents',
#  'abv smells',
#  'abv so',
#  'abv stewed',
#  'abv that',
#  'abv this',
#  'abv well',
#  'abv which',
#  'abv wine',
#  'abv would',
#  'abv yet',
#  'ac',
#  'ac coteaux',
#  'acacia',
#  'acacia along',
#  'acacia and',
#  'acacia apple',
#  'acacia apricot',
#  'acacia aromas',
#  'acacia as',
#  'acacia barrel',
#  'acacia barrels',
#  'acacia bitter',
#  'acacia blossom',
#  'acacia blossoms',
#  'acacia carry',
#  'acacia casks',
#  'acacia chamomile',
#  'acacia citrus',
#  'acacia float',
#  'acacia flower',
#  'acacia flowers',
#  'acacia hawthorne',
#  'acacia herb',
#  'acacia herbs',
#  'acacia honey',
#  'acacia honeydew',
#  'acacia honeyed',
#  'acacia it',
#  'acacia layered',
#  'acacia lead',
#  'acacia lemon',
#  'acacia mediterranean',
#  'acacia mingle',
#  'acacia orange',
#  'acacia orchard',
#  'acacia peach',
#  ...]

# %%
X_train_counts.shape
# Out:
# (90731, 2019329)

# %%
#now we will run multinomial Bayes using just the vectozied data (no tf_idf run)
mnb = MultinomialNB().fit(X_train_counts, y_train)

# %%
print(f"Training Data Score: {mnb.score(X_train_counts, y_train)}")
# Out:
# Training Data Score: 0.789608843724857

# %%
X_test_counts = vect.transform(X_test)

# %%
print(f"MNB on non-tfidf Testing Data Score: {mnb.score(X_test_counts, y_test)}")
# Out:
# MNB on non-tfidf Testing Data Score: 0.26094431953445313

# %% [markdown]
# We can now see our predictive score using just CountVectorized, but with n-grams and numerical "words" removed is much better (.64 vs. .278 with MNB done on vectorized and TF_IDF data without bi-grams or stop words removed.
#
# We will now try the SGDClassifier on the data

# %%
sgdc = SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=42, max_iter=5, tol=None).fit(X_train_counts, y_train)

# %%
print(f"Training Data Score: {sgdc.score(X_train_counts, y_train)}")
# Out:
# Training Data Score: 0.9425664877495012

# %%
print(f"SGDC on non-tfidf Testing Data Score w/ 3-grams: {sgdc.score(X_test_counts, y_test)}")
# Out:
# SGDC on non-tfidf Testing Data Score w/ 3-grams: 0.2871313318344134

# %% [markdown]
# We see a score of .697, which is slightly better, but not much.
#
# Now let's do a TF_IDF transform and feed into both the MNB and SGDC models.

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
mnb3 = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
print(f"Training Data Score: {mnb3.score(X_train_tfidf, y_train)}")
# Out:
# Training Data Score: 0.3470478667710044

# %% [markdown]
# .347! That works worse.
#
# Next is SGDC on TF_IDF data

# %%
sgdc3 = SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=1, max_iter=5, tol=None).fit(X_train_tfidf, y_train)

# %%
print(f"Training Data Score: {sgdc3.score(X_train_tfidf, y_train)}")
# Out:
# Training Data Score: 0.9734930729298696

# %% [markdown]
# Now to run on our test data. First we will have to transform the test X data using our vectorizer (with just transform), and also with tf_idf

# %%
X_test_counts = vect.transform(X_test)

# %%
X_test_counts.shape
# Out:
# (30244, 517778)

# %%
X_test_tfidf = tfidf_transformer.transform(X_test_counts)

# %%
X_test_tfidf.shape
# Out:
# (30244, 517778)

# %%
print(f"Testing Data Score: {sgdc3.score(X_test_tfidf, y_test)}")
# Out:
# Testing Data Score: 0.2884208438037297

# %% [markdown]
# Well that's not nearly as nice. Let's see what our test data looks like in the mnb model

# %%
print(f"Testing Data Score: {sgdc.score(X_test_counts, y_test)}")
# Out:
# Testing Data Score: 0.2517193492924216

# %%
print(f"Testing Data Score: {mnb3.score(X_test_tfidf, y_test)}")
# Out:
# Testing Data Score: 0.20635497950006612

# %%
print(f"Testing Data Score: {mnb.score(X_test_counts, y_test)}")
# Out:
# Testing Data Score: 0.25221531543446635

# %%
X_test_counts
# Out:
# <30244x517778 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2092202 stored elements in Compressed Sparse Row format>

# %%
#let's try just removed the numerical stuff and using only 1-grams in our countvectorizer model
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(stop_words=stop_list)
X_train_counts = vect.fit_transform(X_train)

# %%
vect.get_feature_names()
# Out:
# ['aacacia',
#  'aand',
#  'aaron',
#  'abacela',
#  'abadal',
#  'abadia',
#  'abandon',
#  'abandoned',
#  'abate',
#  'abbazia',
#  'abbey',
#  'abbott',
#  'abbreviated',
#  'abc',
#  'abeille',
#  'abeilles',
#  'abeja',
#  'abel',
#  'abele',
#  'abelis',
#  'abelé',
#  'abernathy',
#  'abeyance',
#  'abide',
#  'abiding',
#  'abilio',
#  'abilities',
#  'ability',
#  'abiouness',
#  'able',
#  'ably',
#  'abnormal',
#  'abnormally',
#  'aboard',
#  'abondante',
#  'aboriginal',
#  'abound',
#  'abounds',
#  'abouriou',
#  'about',
#  'abovde',
#  'above',
#  'abraham',
#  'abrasive',
#  'abrasiveness',
#  'abraxas',
#  'abreu',
#  'abrigo',
#  'abroad',
#  'abrupt',
#  'abruptly',
#  'abruptness',
#  'abruzzo',
#  'absence',
#  'absense',
#  'absent',
#  'absinthe',
#  'absolute',
#  'absolutely',
#  'absorb',
#  'absorbed',
#  'absorbingly',
#  'absurd',
#  'absurdly',
#  'abtsberg',
#  'abundance',
#  'abundant',
#  'abundantly',
#  'abupt',
#  'abused',
#  'abuts',
#  'abuzz',
#  'abv',
#  'ac',
#  'acacia',
#  'academic',
#  'acai',
#  'acccessible',
#  'accelerate',
#  'accelerates',
#  'accent',
#  'accented',
#  'accenting',
#  'accents',
#  'accentuate',
#  'accentuated',
#  'accentuates',
#  'accentuating',
#  'acceptability',
#  'acceptable',
#  'acceptance',
#  'accesible',
#  'access',
#  'accessable',
#  'accesses',
#  'accessibile',
#  'accessibility',
#  'accessible',
#  'accessibly',
#  'accessorized',
#  'accetnes',
#  'accident',
#  'accidental',
#  'acclaimed',
#  'accolade',
#  'accolades',
#  'accommodates',
#  'accompained',
#  'accompanied',
#  'accompanies',
#  'accompaniment',
#  'accompaniments',
#  'accompany',
#  'accompanying',
#  'accomplish',
#  'accomplished',
#  'accomplishes',
#  'accomplishment',
#  'accord',
#  'accordance',
#  'according',
#  'accordingly',
#  'accordini',
#  'accordion',
#  'account',
#  'accountant',
#  'accounted',
#  'accounting',
#  'accounts',
#  'accumulate',
#  'accumulating',
#  'accurate',
#  'accurately',
#  'accused',
#  'accustomed',
#  'ace',
#  'aces',
#  'acetic',
#  'acetone',
#  'achaval',
#  'acheived',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achievements',
#  'achieves',
#  'achieving',
#  'aching',
#  'achingly',
#  'achleiten',
#  'aciar',
#  'acid',
#  'acidhounds',
#  'acidic',
#  'acidically',
#  'acidicy',
#  'acididty',
#  'acidification',
#  'acidified',
#  'acidify',
#  'acidity',
#  'acidiy',
#  'acids',
#  'acidty',
#  'aciidty',
#  'aciprestes',
#  'acitity',
#  'ackhurst',
#  'acknowledged',
#  'acknowledges',
#  'acohol',
#  'aconcagua',
#  'acorn',
#  'acorns',
#  'acorny',
#  'acquaintance',
#  'acquavigna',
#  'acqui',
#  'acquire',
#  'acquired',
#  'acquires',
#  'acquiring',
#  'acquit',
#  'acquits',
#  'acquitted',
#  'acre',
#  'acreage',
#  'acres',
#  'acrid',
#  'acrobat',
#  'acrobatics',
#  'across',
#  'act',
#  'acted',
#  'acting',
#  'action',
#  'active',
#  'actively',
#  'activity',
#  'actor',
#  'actress',
#  'acts',
#  'actual',
#  'actuality',
#  'actually',
#  'acute',
#  'acutely',
#  'ad',
#  'adage',
#  'adam',
#  'adamant',
#  'adami',
#  'adams',
#  'adaptability',
#  'adaptable',
#  'adaptation',
#  'add',
#  'addamo',
#  'added',
#  'addictive',
#  'addictively',
#  'addicts',
#  'adding',
#  'addition',
#  'additional',
#  'additionally',
#  'additions',
#  'additives',
#  'address',
#  'adds',
#  'ade',
#  'adega',
#  'adelaida',
#  'adelaide',
#  'adele',
#  'adelsheim',
#  'adelsheims',
#  'adept',
#  'adequate',
#  'adequately',
#  'adhere',
#  'adherence',
#  'adheres',
#  'adhesive',
#  'adige',
#  'adjacent',
#  'adjectives',
#  'adjoins',
#  'adjunct',
#  'adjusted',
#  'administered',
#  'admirable',
#  'admirably',
#  'admiral',
#  'admiration',
#  'admire',
#  'admired',
#  'admirers',
#  'admission',
#  'admit',
#  'admitted',
#  'admittedly',
#  'admitting',
#  'admixture',
#  'ado',
#  'adolescent',
#  'adolph',
#  'adopted',
#  'adopting',
#  'adopts',
#  'adore',
#  'adored',
#  'adoring',
#  'adorn',
#  'adorned',
#  'adorning',
#  'adornments',
#  'adorns',
#  'adour',
#  'adquate',
#  'adriana',
#  'adrianna',
#  'adriano',
#  'adriatic',
#  'adrienne',
#  'adroitly',
#  'adult',
#  'adults',
#  'advance',
#  'advanced',
#  'advancement',
#  'advances',
#  'advantage',
#  'adventure',
#  'adventurers',
#  'adventurous',
#  'advertised',
#  'advertisement',
#  'advertises',
#  'advertising',
#  'advice',
#  'advisable',
#  'advised',
#  'advocacy',
#  'adènzia',
#  'adèo',
#  'aegean',
#  'aegerter',
#  'aeolia',
#  'aerate',
#  'aerated',
#  'aerates',
#  'aerating',
#  'aeration',
#  'aerator',
#  'aerosmith',
#  'aerospace',
#  'aesthetic',
#  'aesthetics',
#  'afar',
#  'afertaste',
#  'affable',
#  'affair',
#  'affect',
#  'affectation',
#  'affected',
#  'affecting',
#  'affection',
#  'affects',
#  'afficionadoes',
#  'afficionados',
#  'affile',
#  'affiliated',
#  'affinity',
#  'affirm',
#  'affixed',
#  'afflicted',
#  'afforable',
#  'afford',
#  'affordability',
#  'affordable',
#  'affordably',
#  'affording',
#  'affords',
#  'affront',
#  'aficianados',
#  'aficionados',
#  'afield',
#  'afloat',
#  'aflutter',
#  'afoot',
#  'aforementioned',
#  'afoul',
#  'afraid',
#  'afresh',
#  'africa',
#  'african',
#  'africans',
#  'afrikaans',
#  'after',
#  'afteratste',
#  'afterburn',
#  'afterburners',
#  'afterflavors',
#  'aftermath',
#  'afternoon',
#  'afternoons',
#  'afternote',
#  'afternotes',
#  'aftershock',
#  'aftershocks',
#  'aftertaste',
#  'aftertastes',
#  'afterthought',
#  'afterthoughts',
#  'aftertones',
#  'afterward',
#  'afterwards',
#  'again',
#  'against',
#  'agassac',
#  'agate',
#  'agave',
#  'age',
#  'ageabiity',
#  'ageability',
#  'ageabilty',
#  'ageable',
#  'agebrush',
#  'aged',
#  'ageing',
#  'agen',
#  'agenda',
#  'agent',
#  'ager',
#  'ages',
#  'ageworthiness',
#  'ageworthy',
#  'aggression',
#  'aggressive',
#  'aggressively',
#  'aggressiveness',
#  'agile',
#  'agility',
#  'aging',
#  'agiorgitiko',
#  'agiorgitkio',
#  'agiorgitko',
#  'aglianico',
#  'agng',
#  'ago',
#  'agostina',
#  'agoston',
#  'agrapart',
#  'agree',
#  'agreeability',
#  'agreeable',
#  'agreeably',
#  'agrelo',
#  'agressive',
#  'agressively',
#  'agriculture',
#  'agrigento',
#  'agro',
#  'agrocert',
#  'agua',
#  'agueira',
#  'aguia',
#  'aguieira',
#  'agustin',
#  'ah',
#  'ahead',
#  'ahi',
#  'ahn',
#  'ahoy',
#  'ai',
#  'aia',
#  'aid',
#  'aided',
#  'aidil',
#  'aiding',
#  'aids',
#  'aiken',
#  'aim',
#  'aimed',
#  'aiming',
#  'aimless',
#  'aimlessly',
#  'aims',
#  'ain',
#  'aiolo',
#  'air',
#  'airborne',
#  'aired',
#  'airen',
#  'airfield',
#  'airiness',
#  'airing',
#  'airs',
#  'airtime',
#  'airy',
#  'airén',
#  'aisle',
#  'aisles',
#  'aix',
#  'aka',
#  'akin',
#  'akiyoshi',
#  'al',
#  'alabaster',
#  'alain',
#  'alamitos',
#  'alamo',
#  'alamos',
#  'alan',
#  'alana',
#  'alance',
#  'alarid',
#  'alarm',
#  'alarmed',
#  'alarming',
#  'alarmingly',
#  'alaska',
#  'alatus',
#  'alayt',
#  'alazan',
#  'alba',
#  'alban',
#  'albana',
#  'albar',
#  'albarino',
#  'albariño',
#  'albariños',
#  'albarossa',
#  'albeit',
#  'albera',
#  'alberello',
#  'albert',
#  'albertina',
#  'alberto',
#  'albinea',
#  'albola',
#  'albrecht',
#  'alcamo',
#  'alcance',
#  'alcantara',
#  'alchemist',
#  'alchemy',
#  'alcineo',
#  'alcohol',
#  'alcoholic',
#  'aldegheri',
#  'aldehydic',
#  'alden',
#  'alder',
#  'alderbrook',
#  'alderpoint',
#  'aldo',
#  'ale',
#  'aleatico',
#  'alejandro',
#  'alella',
#  'alentejano',
#  'alentejo',
#  'aleramico',
#  'alert',
#  'alessandro',
#  'alessano',
#  'alex',
#  'alexander',
#  'alexandra',
#  'alexandre',
#  'alexandria',
#  'alexandrine',
#  'alfalfa',
#  'alfio',
#  'alfonso',
#  'alfred',
#  'alfredo',
#  'alfresco',
#  'alfrocheiro',
#  'algae',
#  'algarve',
#  'alicante',
#  'alice',
#  'alicia',
#  'alidis',
#  'alienor',
#  'alighieri',
#  'aligi',
#  'align',
#  'aligned',
#  'aligns',
#  'aligote',
#  'aligoté',
#  'alike',
#  'alion',
#  'aliquorous',
#  'aliso',
#  'alisos',
#  'alit',
#  'alitgoté',
#  'alive',
#  'aliénor',
#  'alkaline',
#  'alkalinity',
#  'alkoomi',
#  'all',
#  'alla',
#  'allan',
#  'alle',
#  'alleanza',
#  'allegrini',
#  'allen',
#  'allende',
#  'allergic',
#  'alley',
#  'alliance',
#  'allied',
#  'allier',
#  'alloro',
#  'allotment',
#  'allow',
#  'allowable',
#  'allowed',
#  'allowing',
#  'allows',
#  'alloyed',
#  'allrounder',
#  'allspice',
#  'allude',
#  'alludes',
#  'allure',
#  'allures',
#  'alluring',
#  'alluringly',
#  'alluvial',
#  'allying',
#  'alma',
#  'almaden',
#  'almaterra',
#  'almaviva',
#  'almeida',
#  'almeirim',
#  'almirez',
#  'almond',
#  'almondine',
#  'almonds',
#  'almondy',
#  'almost',
#  'almosty',
#  'aloe',
#  'aloft',
#  'alois',
#  'alone',
#  'along',
#  'alongside',
#  'alonside',
#  'aloof',
#  'alorna',
#  'aloud',
#  'alouette',
#  'aloxe',
#  'alperegis',
#  'alpes',
#  'alpha',
#  'alphonse',
#  'alpilles',
#  'alpine',
#  'alps',
#  'already',
#  'alsace',
#  'alsatian',
#  'also',
#  'alta',
#  'altamira',
#  'altamont',
#  'altamura',
#  'altano',
#  'altar',
#  'altaïr',
#  'alte',
#  'alteo',
#  'alter',
#  'alterations',
#  'alternate',
#  'alternately',
#  'alternating',
#  'alternative',
#  'alternatively',
#  'alternatives',
#  'altesino',
#  'altesse',
#  'although',
#  'altimus',
#  'altiora',
#  'altitude',
#  'altitudes',
#  'alto',
#  'altocedro',
#  'altogether',
#  'altoids',
#  'altos',
#  'altrovino',
#  'alum',
#  'alvarelhão',
#  'alvarinho',
#  'alvarinhos',
#  'alvaro',
#  'alvear',
#  'always',
#  'am',
#  'amabile',
#  'amadieu',
#  'amador',
#  'amaiable',
#  'amalfi',
#  'amalgam',
#  'amalgamated',
#  'amalgamates',
#  'amalgamation',
#  'amalie',
#  'amant',
#  'amaral',
#  'amarante',
#  'amare',
#  'amarela',
#  'amarena',
#  'amaretto',
#  'amaro',
#  'amarone',
#  'amarones',
#  'amass',
#  'amassing',
#  'amavi',
#  'amaze',
#  'amazed',
#  'amazes',
#  'amazing',
#  'amazingly',
#  'ambassador',
#  'amber',
#  'ambiance',
#  'ambient',
#  'ambiguities',
#  'ambiguous',
#  'ambitions',
#  'ambitious',
#  'ambitiously',
#  'amble',
#  'ambles',
#  'ambrogio',
#  'ambrosan',
#  'ambrosia',
#  'ambrosial',
#  'ambruco',
#  'ambré',
#  'ambulance',
#  'amburgo',
#  'ambush',
#  'amd',
#  'ameliorate',
#  'ameliorated',
#  'amenability',
#  'amended',
#  'america',
#  'american',
#  'americanized',
#  'americans',
#  'americna',
#  'amerigo',
#  'amiable',
#  'amici',
#  'amicus',
#  'amid',
#  'amidst',
#  'amigas',
#  'amindst',
#  'amisfield',
#  'amiss',
#  'amity',
#  'amking',
#  'ammo',
#  'ammonia',
#  'ammons',
#  'among',
#  'amongst',
#  'amontillado',
#  'amores',
#  'amorim',
#  'amorphous',
#  'amouller',
#  'amount',
#  'amounts',
#  'amour',
#  'amoureuses',
#  'amp',
#  'amped',
#  'ampelos',
#  'amphibolite',
#  'amphitheater',
#  'amphora',
#  'amphorae',
#  'amphoras',
#  'ample',
#  'ampleness',
#  'amplified',
#  'amplifies',
#  'amplify',
#  'amplifying',
#  'amplitude',
#  'amply',
#  'amps',
#  'ampuis',
#  'amuse',
#  'amusing',
#  'amusingly',
#  'amy',
#  'amélie',
#  'an',
#  'anagram',
#  'analivia',
#  'analog',
#  'analogies',
#  'analogy',
#  'analysis',
#  'analyze',
#  'analyzing',
#  'anam',
#  'anas',
#  'ancellota',
#  'ancellotta',
#  'ancestor',
#  'ancestors',
#  'ancestrale',
#  'ancestry',
#  'ancho',
#  'anchor',
#  'anchored',
#  'anchoring',
#  'anchors',
#  'anchovy',
#  'ancien',
#  'ancienne',
#  'ancient',
#  'ancilla',
#  'ancillary',
#  'ancona',
#  'and',
#  'andbutter',
#  'andcrushed',
#  'andelain',
#  'andeluna',
#  'andersen',
#  'anderson',
#  'andes',
#  'andis',
#  'andlau',
#  'andpeppery',
#  'andrea',
#  'andreas',
#  'andres',
#  'andretti',
#  'andrew',
#  'andré',
#  'ands',
#  'andtangerine',
#  'andvanilla',
#  'andy',
#  'ane',
#  'anf',
#  'anfora',
#  'angel',
#  'angela',
#  'angeles',
#  'angeli',
#  'angelica',
#  'angelina',
#  'angeline',
#  'angelo',
#  'angels',
#  'angelus',
#  'angers',
#  'angimbé',
#  'angiolina',
#  'anglaise',
#  'angle',
#  'angled',
#  'angles',
#  'angludet',
#  'angosto',
#  'angove',
#  'angry',
#  'angst',
#  'angular',
#  'angularities',
#  'angularity',
#  'angélus',
#  'anima',
#  'animal',
#  'animale',
#  'animalistic',
#  'animals',
#  'animate',
#  'animated',
#  'animates',
#  'animating',
#  'animo',
#  'anise',
#  'aniseed',
#  'aniseeed',
#  'aniseseed',
#  'anisette',
#  'anita',
#  'anjou',
#  'anjoy',
#  'anka',
#  'anke',
#  'ann',
#  'anna',
#  'annamaria',
#  'annapolis',
#  'annata',
#  'anne',
#  'annette',
#  'annick',
#  'anniversaries',
#  'anniversary',
#  'annotate',
#  'annotated',
#  'announce',
#  'announced',
#  'announcement',
#  'announces',
#  'announcing',
#  'annoyance',
#  'annoying',
#  'annoyingly',
#  'annual',
#  'annually',
#  'annunziata',
#  'annurca',
#  'anointed',
#  'anomaly',
#  'anonymous',
#  'anorexic',
#  'another',
#  'anselmi',
#  'anselmo',
#  'answer',
#  'answers',
#  'ant',
#  'ante',
#  'anthill',
#  'anthology',
#  'anthony',
#  'anti',
#  'antichello',
#  'anticipate',
#  'anticipated',
#  'anticipates',
#  'anticipating',
#  'anticipation',
#  'antico',
#  'antidote',
#  'antiformulaic',
#  'antimo',
#  'antinori',
#  'antipasti',
#  'antipasto',
#  'antique',
#  'antiquum',
#  'antiseptic',
#  'antithesis',
#  'antle',
#  'antoine',
#  'anton',
#  'antonia',
#  'antonin',
#  'antonini',
#  'antonio',
#  'antony',
#  'antrum',
#  'ants',
#  'antão',
#  'antónio',
#  'anvil',
#  'any',
#  'anymore',
#  'anyone',
#  'anything',
#  'anytime',
#  'anyway',
#  'anywhere',
#  'aoife',
#  'aomas',
#  'aop',
#  'aormas',
#  'apalta',
#  'apart',
#  'apartado',
#  'aperitif',
#  'aperitifs',
#  'aperitivo',
#  'aperos',
#  'aperture',
#  'apex',
#  'apianae',
#  'apicots',
#  'aplenty',
#  'aplets',
#  'aplomb',
#  'apogee',
#  'apollo',
#  'apolloni',
#  'apologies',
#  'apologize',
#  'apologizing',
#  'appalachian',
#  'apparent',
#  'apparently',
#  'apparita',
#  'appassimento',
#  'appassiti',
#  'appeal',
#  'appealing',
#  'appealingly',
#  'appeals',
#  'appear',
#  'appearance',
#  'appearances',
#  'appeared',
#  'appearing',
#  'appears',
#  'appease',
#  'appellated',
#  'appellation',
#  'appellations',
#  'appetising',
#  'appetite',
#  ...]

# %%
X_test_counts = vect.transform(X_test)

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
X_test_tfidf = tfidf_transformer.transform(X_test_counts)

# %%
mnb = MultinomialNB().fit(X_train_counts, y_train)

# %%
print(f"Training Data Score: {mnb.score(X_train_counts, y_train)}")
# Out:
# Training Data Score: 0.3972953014956299

# %%
print(f"Testing Data Score: {mnb.score(X_test_counts, y_test)}")
# Out:
# Testing Data Score: 0.23148393069699774

# %%
sgdc = SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=42, max_iter=5, tol=None).fit(X_train_counts, y_train)

# %%
print(f"Training Data Score: {sgdc.score(X_train_counts, y_train)}")
# Out:
# Training Data Score: 0.30471393459787727

# %%
print(f"Testing Data Score: {sgdc.score(X_test_counts, y_test)}")
# Out:
# Testing Data Score: 0.1983533924084116

# %%
mnb_tf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
print(f"Training Data Score: {mnb_tf.score(X_train_tfidf, y_train)}")
# Out:
# Training Data Score: 0.27803066206698923

# %%
sgdc_tf = SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=42, max_iter=5, tol=None).fit(X_train_tfidf, y_train)

# %%
print(f"Training Data Score: {sgdc_tf.score(X_train_tfidf, y_train)}")
# Out:
# Training Data Score: 0.4596775082386395

# %%
print(f"Testing Data Score: {sgdc_tf.score(X_test_tfidf, y_test)}")
# Out:
# Testing Data Score: 0.20827271524930566

# %%
sgdc = SGDClassifier().fit(X_train_counts, y_train)
# Out:
# C:\Users\Aaron\Anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
print(f"Training Data Score: {sgdc.score(X_train_counts, y_train)}")
# Out:
# Training Data Score: 0.3215659476915277

# %%
print(f"Testing Data Score: {sgdc.score(X_test_counts, y_test)}")
# Out:
# Testing Data Score: 0.1961711413834149

# %%
sgdc = SGDClassifier().fit(X_train_tfidf, y_train)
# Out:
# C:\Users\Aaron\Anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
print(f"Training Data Score: {sgdc.score(X_train_tfidf, y_train)}")
# Out:
# Training Data Score: 0.4641743174879589

# %%
print(f"Testing Data Score: {sgdc.score(X_test_tfidf, y_test)}")
# Out:
# Testing Data Score: 0.20827271524930566

# %%
#now let's try a CountVectorizer that doesn't remove the stop words, but has a minimum doc freq of 2
vect = CountVectorizer(min_df=3, stop_words=stop_list, ngram_range=(1,2))
X_train_counts = vect.fit_transform(X_train)

# %%
vect = CountVectorizer(stop_words=stop_list, ngram_range=(1,2))
X_train_counts = vect.fit_transform(X_train)

# %%
vect.get_feature_names()
# Out:
# ['aaron',
#  'aaron jackson',
#  'aaron pott',
#  'abacela',
#  'abandon',
#  'abate',
#  'abate fetel',
#  'abbey',
#  'abbey ridge',
#  'abbott',
#  'abbreviated',
#  'abbreviated finish',
#  'abeja',
#  'abelé',
#  'abilities',
#  'ability',
#  'ability of',
#  'ability to',
#  'able',
#  'able to',
#  'ably',
#  'ably marries',
#  'abnormal',
#  'abound',
#  'abound along',
#  'abound and',
#  'abound from',
#  'abound here',
#  'abound in',
#  'abound it',
#  'abound on',
#  'abound the',
#  'abound there',
#  'abound throughout',
#  'abound while',
#  'abound with',
#  'abounds',
#  'abounds in',
#  'abounds on',
#  'abounds with',
#  'abouriou',
#  'abouriou grape',
#  'about',
#  'about acid',
#  'about all',
#  'about an',
#  'about and',
#  'about any',
#  'about anything',
#  'about as',
#  'about average',
#  'about balance',
#  'about berry',
#  'about black',
#  'about bright',
#  'about but',
#  'about buttered',
#  'about chardonnay',
#  'about cherries',
#  'about citrus',
#  'about complexity',
#  'about crisp',
#  'about dark',
#  'about delicious',
#  'about dry',
#  'about easy',
#  'about elegance',
#  'about everything',
#  'about expressing',
#  'about feel',
#  'about finesse',
#  'about five',
#  'about four',
#  'about fresh',
#  'about freshness',
#  'about fruit',
#  'about fruitiness',
#  'about half',
#  'about how',
#  'about in',
#  'about it',
#  'about its',
#  'about juicy',
#  'about lemon',
#  'about medium',
#  'about minerality',
#  'about months',
#  'about more',
#  'about new',
#  'about nuance',
#  'about oak',
#  'about of',
#  'about one',
#  'about opening',
#  'about perfect',
#  'about power',
#  'about pure',
#  'about ready',
#  'about red',
#  'about refreshment',
#  'about rich',
#  'about right',
#  'about ripe',
#  'about sheer',
#  'about spice',
#  'about structure',
#  'about subtlety',
#  'about summer',
#  'about sweet',
#  'about texture',
#  'about that',
#  'about the',
#  'about these',
#  'about this',
#  'about three',
#  'about to',
#  'about two',
#  'about was',
#  'about what',
#  'about white',
#  'about year',
#  'above',
#  'above all',
#  'above and',
#  'above average',
#  'above chunky',
#  'above everything',
#  'above its',
#  'above nuits',
#  'above sea',
#  'above the',
#  'above their',
#  'above water',
#  'abrasive',
#  'abrasive acidity',
#  'abrasive and',
#  'abrasive but',
#  'abrasive finish',
#  'abrasive in',
#  'abrasive mouthfeel',
#  'abrasive on',
#  'abrasive palate',
#  'abrasive plum',
#  'abrasive residual',
#  'abrasive tannic',
#  'abrasive tannins',
#  'abrasive while',
#  'abrasive with',
#  'abrasiveness',
#  'abrupt',
#  'abrupt and',
#  'abrupt astringent',
#  'abrupt bitter',
#  'abrupt drying',
#  'abrupt finish',
#  'abrupt on',
#  'abruptly',
#  'abruptly with',
#  'abruzzo',
#  'abruzzo and',
#  'abruzzo that',
#  'absence',
#  'absence of',
#  'absent',
#  'absolute',
#  'absolute concentration',
#  'absolute delight',
#  'absolute dryness',
#  'absolutely',
#  'absolutely beautiful',
#  'absolutely black',
#  'absolutely clean',
#  'absolutely dazzling',
#  'absolutely delicious',
#  'absolutely demands',
#  'absolutely dry',
#  'absolutely first',
#  'absolutely fresh',
#  'absolutely gorgeous',
#  'absolutely loaded',
#  'absolutely lovely',
#  'absolutely no',
#  'absorb',
#  'absorbed',
#  'abundance',
#  'abundance and',
#  'abundance but',
#  'abundance in',
#  'abundance it',
#  'abundance of',
#  'abundance with',
#  'abundant',
#  'abundant aromas',
#  'abundant baking',
#  'abundant barrel',
#  'abundant black',
#  'abundant blue',
#  'abundant but',
#  'abundant cherry',
#  'abundant coffee',
#  'abundant dark',
#  'abundant floral',
#  'abundant fruit',
#  'abundant in',
#  'abundant notes',
#  'abundant oak',
#  'abundant orange',
#  'abundant red',
#  'abundant savory',
#  'abundant spice',
#  'abundant stone',
#  'abundant tropical',
#  'abundant vanilla',
#  'abundant wood',
#  'abundant yet',
#  'abundantly',
#  'abundantly floral',
#  'abundantly tannic',
#  'abv',
#  'abv and',
#  'abv but',
#  'abv it',
#  'abv this',
#  'acacia',
#  'acacia and',
#  'acacia aromas',
#  'acacia barrels',
#  'acacia blossom',
#  'acacia flower',
#  'acacia flowers',
#  'acacia honey',
#  'acacia spanish',
#  'acacia the',
#  'acacia with',
#  'acacia wood',
#  'academic',
#  'acai',
#  'acai fruit',
#  'accent',
#  'accent alongside',
#  'accent an',
#  'accent and',
#  'accent aromas',
#  'accent basic',
#  'accent berry',
#  'accent black',
#  'accent blackberry',
#  'accent blueberry',
#  'accent bright',
#  'accent cherry',
#  'accent citrus',
#  'accent core',
#  'accent crisp',
#  'accent dark',
#  'accent dried',
#  'accent drink',
#  'accent earthy',
#  'accent flavors',
#  'accent fleshy',
#  'accent fresh',
#  'accent in',
#  'accent is',
#  'accent it',
#  'accent its',
#  'accent juicy',
#  'accent lingers',
#  'accent mature',
#  'accent medium',
#  'accent modest',
#  'accent notes',
#  'accent of',
#  'accent on',
#  'accent pear',
#  'accent pineapple',
#  'accent pink',
#  'accent plum',
#  'accent pretty',
#  'accent raspberry',
#  'accent raw',
#  'accent red',
#  'accent ripe',
#  'accent sweet',
#  'accent tart',
#  'accent that',
#  'accent the',
#  'accent this',
#  'accent to',
#  'accent unfolds',
#  'accent while',
#  'accent yellow',
#  'accented',
#  'accented by',
#  'accented cherry',
#  'accented finish',
#  'accented flavors',
#  'accented in',
#  'accented oak',
#  'accented wine',
#  'accented with',
#  'accenting',
#  'accenting aromas',
#  'accenting berry',
#  'accenting black',
#  'accenting flavors',
#  'accenting its',
#  'accenting ripe',
#  'accenting the',
#  'accents',
#  'accents add',
#  'accents an',
#  'accents and',
#  'accents are',
#  'accents around',
#  'accents as',
#  'accents bright',
#  'accents cherry',
#  'accents complement',
#  'accents dried',
#  'accents drink',
#  'accents emerge',
#  'accents finishes',
#  'accents flavors',
#  'accents fresh',
#  'accents from',
#  'accents full',
#  'accents give',
#  'accents here',
#  'accents in',
#  'accents it',
#  'accents its',
#  'accents lean',
#  'accents like',
#  'accents linger',
#  'accents make',
#  'accents mark',
#  'accents medium',
#  'accents notes',
#  'accents of',
#  'accents on',
#  'accents overall',
#  'accents pineapple',
#  'accents ripe',
#  'accents soft',
#  'accents subtle',
#  'accents that',
#  'accents the',
#  'accents there',
#  'accents this',
#  'accents throughout',
#  'accents to',
#  'accents toasty',
#  'accents while',
#  'accents with',
#  'accents you',
#  'accentuate',
#  'accentuate its',
#  'accentuate the',
#  'accentuated',
#  'accentuated by',
#  'accentuates',
#  'accentuates both',
#  'accentuates its',
#  'accentuates the',
#  'accentuating',
#  'accentuating flavors',
#  'accentuating the',
#  'acceptable',
#  'acceptable as',
#  'acceptable but',
#  'acceptable this',
#  'acceptable wine',
#  'access',
#  'access to',
#  'accessibility',
#  'accessible',
#  'accessible and',
#  'accessible at',
#  'accessible blackberry',
#  'accessible blend',
#  'accessible but',
#  'accessible chenin',
#  'accessible drink',
#  'accessible enjoy',
#  'accessible feel',
#  'accessible flavors',
#  'accessible fruity',
#  'accessible it',
#  'accessible its',
#  'accessible mouthfeel',
#  'accessible now',
#  'accessible of',
#  'accessible offering',
#  'accessible palate',
#  'accessible red',
#  'accessible selection',
#  'accessible so',
#  'accessible style',
#  'accessible tannins',
#  'accessible than',
#  'accessible thanks',
#  'accessible the',
#  'accessible this',
#  'accessible to',
#  'accessible white',
#  'accessible wine',
#  'accessible with',
#  'accessible yet',
#  'accessible young',
#  'accessibly',
#  'accessibly priced',
#  'accident',
#  'acclaimed',
#  'acclaimed vintage',
#  'accolades',
#  'accompanied',
#  'accompanied by',
#  'accompanies',
#  'accompanies ripe',
#  'accompanies the',
#  'accompaniment',
#  'accompaniment for',
#  'accompaniment to',
#  'accompaniments',
#  'accompany',
#  'accompany food',
#  'accompany its',
#  'accompany rich',
#  'accompany ripe',
#  'accompany simple',
#  'accompany the',
#  'accompanying',
#  'accompanying acidity',
#  'accompanying the',
#  'accomplishes',
#  'accomplishes that',
#  'accomplishment',
#  'accomplishment and',
#  'accordance',
#  'accordance with',
#  'according',
#  'according to',
#  'accordingly',
#  'account',
#  'account for',
#  'accounted',
#  'accounted for',
#  'accounting',
#  'accounting for',
#  'accounts',
#  'accounts for',
#  'accumulate',
#  'accumulate in',
#  'accurate',
#  'accurately',
#  'accustomed',
#  'accustomed to',
#  'ace',
#  'acetic',
#  'achaval',
#  'achaval ferrer',
#  'achieve',
#  'achieve balance',
#  'achieve it',
#  'achieve optimal',
#  'achieve that',
#  'achieve this',
#  'achieved',
#  'achieved with',
#  'achievement',
#  'achievement in',
#  'achieves',
#  'achieves balance',
#  'achieves elegance',
#  'achieves good',
#  'achieves nice',
#  'achieves wonderful',
#  'achieving',
#  'aching',
#  'achingly',
#  'achingly pure',
#  'achingly sweet',
#  'acid',
#  'acid and',
#  'acid are',
#  'acid backbone',
#  'acid backed',
#  'acid backing',
#  'acid balance',
#  'acid base',
#  'acid based',
#  'acid but',
#  'acid drink',
#  'acid driven',
#  'acid finish',
#  'acid flavors',
#  'acid for',
#  'acid fruit',
#  'acid in',
#  'acid inspired',
#  'acid is',
#  'acid it',
#  'acid keeps',
#  'acid laced',
#  'acid level',
#  'acid lovers',
#  'acid mouthfeel',
#  'acid on',
#  'acid or',
#  'acid palate',
#  'acid pinot',
#  'acid red',
#  'acid rich',
#  'acid so',
#  'acid structure',
#  'acid style',
#  'acid tannin',
#  'acid than',
#  'acid that',
#  'acid the',
#  'acid to',
#  'acid underpinning',
#  'acid vintage',
#  'acid while',
#  'acid white',
#  'acid wine',
#  'acid with',
#  'acid year',
#  'acidic',
#  'acidic aftertaste',
#  'acidic almost',
#  'acidic an',
#  'acidic and',
#  'acidic as',
#  'acidic backbone',
#  'acidic bite',
#  'acidic bitterness',
#  'acidic black',
#  'acidic bone',
#  'acidic but',
#  'acidic chardonnay',
#  'acidic citrus',
#  'acidic crispness',
#  'acidic cut',
#  'acidic despite',
#  'acidic edge',
#  'acidic energy',
#  'acidic enough',
#  'acidic feel',
#  'acidic finish',
#  'acidic flavors',
#  'acidic for',
#  'acidic fresh',
#  'acidic freshness',
#  'acidic giving',
#  'acidic in',
#  'acidic it',
#  'acidic kick',
#  'acidic lift',
#  'acidic making',
#  'acidic minerality',
#  'acidic minerally',
#  'acidic mouthfeel',
#  'acidic now',
#  'acidic on',
#  'acidic one',
#  'acidic or',
#  'acidic palate',
#  'acidic pinot',
#  'acidic pop',
#  'acidic push',
#  'acidic red',
#  'acidic scour',
#  'acidic sharpness',
#  'acidic side',
#  'acidic sizzle',
#  'acidic snap',
#  'acidic so',
#  'acidic streak',
#  'acidic structure',
#  'acidic style',
#  'acidic tang',
#  'acidic tannic',
#  'acidic tastes',
#  'acidic than',
#  'acidic that',
#  'acidic the',
#  'acidic this',
#  'acidic thrill',
#  'acidic to',
#  'acidic verve',
#  'acidic which',
#  'acidic while',
#  'acidic white',
#  'acidic wine',
#  'acidic with',
#  'acidic yet',
#  'acidic young',
#  'acidic zest',
#  'acidic zing',
#  'acidification',
#  'acidified',
#  'acidity',
#  'acidity accents',
#  'acidity accentuates',
#  'acidity accompanies',
#  'acidity accompanying',
#  'acidity acting',
#  'acidity acts',
#  'acidity add',
#  'acidity adding',
#  'acidity adds',
#  'acidity against',
#  'acidity age',
#  'acidity alcohol',
#  'acidity all',
#  'acidity allow',
#  'acidity allowing',
#  'acidity allows',
#  'acidity almost',
#  'acidity along',
#  'acidity alongside',
#  'acidity already',
#  'acidity also',
#  'acidity although',
#  'acidity amid',
#  'acidity amidst',
#  'acidity an',
#  'acidity and',
#  'acidity anise',
#  'acidity apple',
#  'acidity apples',
#  'acidity apricot',
#  'acidity are',
#  'acidity around',
#  'acidity as',
#  'acidity associated',
#  'acidity at',
#  'acidity attractive',
#  'acidity backed',
#  'acidity backs',
#  'acidity baked',
#  'acidity balance',
#  'acidity balanced',
#  'acidity balances',
#  'acidity balancing',
#  'acidity beautiful',
#  'acidity beautifully',
#  'acidity becomes',
#  'acidity before',
#  'acidity behind',
#  'acidity beneath',
#  'acidity berry',
#  'acidity best',
#  'acidity beyond',
#  'acidity big',
#  'acidity bit',
#  'acidity bitter',
#  'acidity black',
#  'acidity blackberry',
#  'acidity blend',
#  'acidity blends',
#  'acidity bold',
#  'acidity bolstering',
#  'acidity boosts',
#  'acidity both',
#  'acidity bright',
#  'acidity brighten',
#  'acidity brightening',
#  'acidity brightens',
#  'acidity brings',
#  'acidity briny',
#  'acidity brisk',
#  'acidity bristles',
#  'acidity buoys',
#  'acidity bursting',
#  'acidity bursts',
#  'acidity but',
#  'acidity can',
#  'acidity candied',
#  'acidity carries',
#  'acidity carry',
#  'acidity carrying',
#  'acidity cellar',
#  'acidity chalky',
#  'acidity cherry',
#  'acidity citrus',
#  'acidity classic',
#  'acidity clean',
#  'acidity cleanses',
#  'acidity closes',
#  'acidity coffee',
#  'acidity combine',
#  'acidity combined',
#  'acidity combines',
#  'acidity combining',
#  'acidity come',
#  'acidity comes',
#  'acidity coming',
#  'acidity complement',
#  'acidity complements',
#  'acidity complete',
#  'acidity completes',
#  'acidity complex',
#  'acidity concentrated',
#  'acidity contrast',
#  'acidity contrasts',
#  'acidity contributes',
#  'acidity could',
#  'acidity counters',
#  'acidity coupled',
#  'acidity cranberry',
#  'acidity creamy',
#  'acidity create',
#  'acidity creates',
#  'acidity creating',
#  'acidity crisp',
#  'acidity cuts',
#  'acidity cutting',
#  'acidity dances',
#  'acidity dancing',
#  'acidity dark',
#  'acidity deep',
#  'acidity defines',
#  'acidity delicate',
#  'acidity delicious',
#  'acidity delightful',
#  'acidity delightfully',
#  'acidity delivers',
#  'acidity despite',
#  'acidity developing',
#  'acidity does',
#  'acidity doesn',
#  'acidity dominant',
#  'acidity dominate',
#  'acidity dominates',
#  'acidity don',
#  'acidity down',
#  'acidity drawing',
#  'acidity dried',
#  'acidity drink',
#  'acidity drive',
#  'acidity driven',
#  'acidity drives',
#  'acidity driving',
#  'acidity dry',
#  'acidity dryness',
#  'acidity dusty',
#  'acidity earthy',
#  'acidity easy',
#  'acidity elegance',
#  'acidity elegant',
#  'acidity ending',
#  'acidity energizes',
#  'acidity enhances',
#  'acidity enjoy',
#  'acidity enlivens',
#  'acidity ensure',
#  'acidity ensures',
#  'acidity even',
#  'acidity everything',
#  'acidity extends',
#  'acidity feels',
#  'acidity fermented',
#  'acidity fill',
#  'acidity fine',
#  'acidity finely',
#  'acidity finish',
#  'acidity finished',
#  'acidity finishes',
#  'acidity finishing',
#  'acidity firm',
#  'acidity flavors',
#  'acidity floral',
#  'acidity focused',
#  'acidity followed',
#  'acidity for',
#  'acidity fortunately',
#  'acidity fragrant',
#  'acidity frame',
#  'acidity framed',
#  'acidity frames',
#  'acidity framing',
#  'acidity fresh',
#  'acidity freshens',
#  'acidity freshness',
#  'acidity from',
#  'acidity fruit',
#  'acidity fruitiness',
#  'acidity fruity',
#  'acidity full',
#  'acidity fun',
#  'acidity generates',
#  'acidity generous',
#  'acidity gets',
#  'acidity give',
#  'acidity given',
#  'acidity gives',
#  'acidity giving',
#  'acidity glass',
#  'acidity go',
#  'acidity goes',
#  'acidity good',
#  'acidity gorgeous',
#  'acidity grapefruit',
#  'acidity great',
#  'acidity green',
#  'acidity grippy',
#  'acidity guarantee',
#  'acidity hard',
#  'acidity has',
#  'acidity have',
#  'acidity heavy',
#  'acidity help',
#  'acidity helps',
#  'acidity herbal',
#  'acidity here',
#  'acidity highlighting',
#  'acidity highlights',
#  'acidity hint',
#  'acidity hints',
#  'acidity hits',
#  'acidity hold',
#  'acidity holding',
#  'acidity holds',
#  'acidity honey',
#  'acidity however',
#  'acidity if',
#  'acidity imparts',
#  'acidity in',
#  'acidity indicates',
#  'acidity integrated',
#  'acidity intense',
#  'acidity into',
#  'acidity is',
#  'acidity it',
#  'acidity its',
#  'acidity jammy',
#  'acidity jolts',
#  'acidity juicy',
#  'acidity jumps',
#  'acidity just',
#  'acidity keep',
#  'acidity keeping',
#  'acidity keeps',
#  'acidity kicks',
#  'acidity la',
#  'acidity laced',
#  'acidity layered',
#  'acidity layers',
#  'acidity lead',
#  'acidity leading',
#  'acidity leads',
#  'acidity leafy',
#  'acidity lean',
#  'acidity leave',
#  'acidity leaves',
#  'acidity leaving',
#  'acidity lemon',
#  'acidity lend',
#  'acidity lending',
#  'acidity lends',
#  'acidity level',
#  'acidity licorice',
#  'acidity lift',
#  'acidity lifting',
#  'acidity lifts',
#  'acidity light',
#  'acidity lightens',
#  'acidity lightly',
#  'acidity like',
#  'acidity lime',
#  'acidity lines',
#  'acidity lingering',
#  'acidity lingers',
#  'acidity little',
#  'acidity lively',
#  'acidity livens',
#  'acidity loamy',
#  'acidity lots',
#  'acidity low',
#  'acidity luscious',
#  'acidity luxurious',
#  'acidity made',
#  'acidity maintaining',
#  'acidity maintains',
#  'acidity make',
#  'acidity makes',
#  'acidity making',
#  'acidity mark',
#  'acidity marks',
#  'acidity medium',
#  'acidity meld',
#  'acidity melon',
#  'acidity mild',
#  'acidity mineral',
#  'acidity minerality',
#  'acidity minerally',
#  'acidity mix',
#  'acidity moderate',
#  'acidity modest',
#  'acidity more',
#  'acidity mouthwatering',
#  'acidity nectarine',
#  'acidity needed',
#  'acidity needing',
#  'acidity nice',
#  'acidity nicely',
#  'acidity not',
#  'acidity note',
#  'acidity nothing',
#  'acidity oak',
#  'acidity oaky',
#  'acidity of',
#  'acidity off',
#  'acidity offer',
#  'acidity offering',
#  'acidity offers',
#  'acidity offset',
#  'acidity offsets',
#  'acidity oliver',
#  'acidity on',
#  'acidity once',
#  'acidity only',
#  'acidity or',
#  'acidity orange',
#  'acidity over',
#  'acidity overall',
#  'acidity pair',
#  'acidity pairs',
#  'acidity partners',
#  'acidity peach',
#  'acidity pear',
#  'acidity penetrates',
#  'acidity perfect',
#  'acidity perfumed',
#  'acidity perhaps',
#  'acidity perks',
#  'acidity picks',
#  'acidity pierces',
#  'acidity pineapple',
#  'acidity pithy',
#  'acidity plenty',
#  'acidity plum',
#  'acidity plus',
#  'acidity powerful',
#  'acidity powers',
#  'acidity presenting',
#  'acidity presents',
#  'acidity preserves',
#  'acidity pretty',
#  'acidity prevents',
#  'acidity produced',
#  'acidity promise',
#  'acidity propelling',
#  'acidity propping',
#  'acidity provide',
#  'acidity provides',
#  'acidity providing',
#  'acidity pulls',
#  'acidity pulses',
#  'acidity pumping',
#  'acidity push',
#  'acidity pushes',
#  'acidity pushing',
#  'acidity puts',
#  'acidity quick',
#  'acidity quite',
#  'acidity racy',
#  'acidity raspberry',
#  'acidity rather',
#  'acidity raw',
#  'acidity ready',
#  'acidity really',
#  'acidity red',
#  'acidity reflecting',
#  'acidity refreshes',
#  'acidity refreshing',
#  'acidity remains',
#  'acidity result',
#  'acidity resulting',
#  'acidity reverberate',
#  'acidity reverberates',
#  'acidity rich',
#  'acidity right',
#  'acidity ripe',
#  'acidity round',
#  'acidity rounded',
#  'acidity running',
#  'acidity runs',
#  'acidity saline',
#  'acidity salty',
#  'acidity saucy',
#  'acidity saves',
#  'acidity savory',
#  'acidity scours',
#  'acidity screw',
#  'acidity screwcap',
#  'acidity seems',
#  'acidity sends',
#  'acidity serve',
#  ...]

# %%
X_test_counts = vect.transform(X_test)

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
X_test_tfidf = tfidf_transformer.transform(X_test_counts)

# %%
mnb = MultinomialNB().fit(X_train_counts, y_train)

# %%
print(f"Training Data Score: {mnb.score(X_train_counts, y_train)}")
# Out:
# Training Data Score: 0.6836362434008222

# %%
print(f"Testing Data Score: {mnb.score(X_test_counts, y_test)}")
# Out:
# Testing Data Score: 0.26626768945906626

# %%
sgdc = SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=42, max_iter=5, tol=None).fit(X_train_counts, y_train)

# %%
print(f"Training Data Score: {sgdc.score(X_train_counts, y_train)}")
# Out:
# Training Data Score: 0.6254532629421036

# %%
print(f"Testing Data Score: {sgdc.score(X_test_counts, y_test)}")
# Out:
# Testing Data Score: 0.24189921967993652

# %%
mnb = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
print(f"Training Data Score: {mnb.score(X_train_tfidf, y_train)}")
# Out:
# Training Data Score: 0.6646791063693777

# %%
print(f"Testing Data Score: {mnb.score(X_test_tfidf, y_test)}")
# Out:
# Testing Data Score: 0.6031278931358286

# %%
sgdc = SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=42, max_iter=5, tol=None).fit(X_train_tfidf, y_train)

# %%
print(f"Training Data Score: {sgdc.score(X_train_tfidf, y_train)}")
# Out:
# Training Data Score: 0.912896363977031

# %%
print(f"Testing Data Score: {sgdc.score(X_test_tfidf, y_test)}")
# Out:
# Testing Data Score: 0.2785676497817749

# %%
print(sgdc.predict(X_test_tfidf[3006]))
print(y_test[3006])
# Out:
# [85]
# 85

# %%
predicted = sgdc.predict(X_test_tfidf)

# %%
metrics.accuracy_score(y_test, predicted)
# Out:
# 0.2785676497817749

# %%
metrics.mean_squared_error(y_test, predicted)
# Out:
# 5.302241766962042

# %%
metrics.mean_absolute_error(y_test, predicted)
# Out:
# 1.6391019706388044

# %%
#I was able to get a 27% accurate model (of exact scores!) using tf_idf with a sgdc model. The details are:
#vect = CountVectorizer(min_df=3, stop_words=stop_list, ngram_range=(1,2))
#tfidf_transformer = TfidfTransformer()
#sgdc = SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=42, max_iter=5, tol=None).fit(X_train_tfidf, y_train)

# %%
def desc_predict(words):
    words_list = [words]
    #words_array = np.array(words_list).reshape(-1,1)
    words_count = vect.transform(words_list)
    words_tfidf = tfidf_transformer.transform(words_count)
    predict_score = sgdc.predict(words_tfidf)
    print("This wine deserves a score of...")
    print(predict_score[0])

# %%
desc_predict('This wine has hints of blackberry and a surprisingly bright feel.\
             Floral notes can be discerned followed by a strong, crisp finish')
# Out:
# This wine deserves a score of...
# 88

# %%
desc_predict('This wine is not very good')
# Out:
# This wine deserves a score of...
# 82

# %%
desc_predict("This is a fantastic wine, that deserves to be cherished and drunk upon special occasions.")
# Out:
# This wine deserves a score of...
# 91

# %%
desc_predict('Hearty, bold, and breathtaking - this wine is outstanding.')
# Out:
# This wine deserves a score of...
# 96

# %%
desc_predict('You should avoid this wine.')
# Out:
# This wine deserves a score of...
# 80

# %%
desc_predict('Earthy, woody, with a hint of berry juicy')
# Out:
# This wine deserves a score of...
# 84

# %%
desc_predict("This wine contains some material over 100 years old, but shows no signs of fragility. Instead, it's concentrated through age and should hold in the bottle indefinitely. It's dark coffee-brown in color, with delectable aromas of rancio, dried fig, molasses and black tea, yet despite enormous concentration avoids excessive weight. And it's amazingly complex and fresh on the nearly endless finish.")
# Out:
# This wine deserves a score of...
# 100

# %%
desc_predict("aromas of seashell and hints of turnip abound. A slight fishy taste is preceeded by a mushy mouthfeel")
# Out:
# This wine deserves a score of...
# 82

# %%
desc_predict("Triumphant and bold, this wine astounds with new tastes upon every sip. It hints at rosemary then delivers a punch of juiciness")
# Out:
# This wine deserves a score of...
# 92

# %%
desc_predict("berry juicy")
# Out:
# This wine deserves a score of...
# 88
